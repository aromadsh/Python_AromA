# %%
import folium
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wifi = pd.read_csv("전국무료와이파이표준데이터.csv", encoding="utf-8")

# %%
wifi.head()
# Out:
#                         설치장소명                설치장소상세    설치시도명 설치시군구명 설치시설구분  \
# 0                천지연 공영주차장1-1                  천정-동  제주특별자치도   서귀포시   편의시설
# 1                천지연 공영주차장1-2                  천정-남  제주특별자치도   서귀포시   편의시설
# 2  천지동자원순환센터 (아랑조을거리입구 서 )1-1  천지동 재활용지원센터 옆 KT주-동남  제주특별자치도   서귀포시   교통시설
# 3  천지동자원순환센터 (아랑조을거리입구 서 )1-2  천지동 재활용지원센터 옆 KT주-남서  제주특별자치도   서귀포시   교통시설
# 4                   아랑조을거리2-1           CCTV 폴 상부 서  제주특별자치도   서귀포시     관광
#
#   서비스제공사명        와이파이SSID 설치년월                 소재지도로명주소  \
# 0      KT  Jeju Free WiFI  NaN      제주특별자치도 서귀포시 서문로 16
# 1      KT  Jeju Free WiFI  NaN      제주특별자치도 서귀포시 서문로 16
# 2      KT  Jeju Free WiFI  NaN                      NaN
# 3      KT  Jeju Free WiFI  NaN                      NaN
# 4      KT  Jeju Free WiFI  NaN  제주특별자치도 서귀포시 중앙로59번길 16
#
#                    소재지지번주소  관리기관명      관리기관전화번호         위도          경도  \
# 0   제주특별자치도 서귀포시 서귀동 305-1  정보정책과  064-710-2352  33.251523  126.559351
# ...

# %%
wifi["와이파이SSID"].fillna("미정", inplace=True)
wifi["소재지도로명주소"].fillna("미정", inplace=True)
wifi["소재지지번주소"].fillna("미정", inplace=True)

# %%
wifi.drop("설치년월", axis=1, inplace=True)

# %%
wifi = wifi.dropna()

# %%
wifi_map = wifi[['설치시도명', '위도', '경도']]

# %%
wifi_map.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26648 entries, 0 to 26806
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   설치시도명   26648 non-null  object
#  1   위도      26648 non-null  float64
#  2   경도      26648 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 832.8+ KB

# %%
# map_osm = folium.Map(location=[37.557945, 126.99419], zoom_start=11)

for region in set(wifi['설치시도명']):
    wifi_from = wifi_map[wifi_map["설치시도명"] == region]
    print(wifi_map["위도"], wifi_map["경도"])
#     marker = folium.CircleMarker([wifi_map['위도'], wifi_map['경도']]) # 위치
#                                   radius=count/10 + 10,                 # 범위
#                                   color='#3186cc',            # 선 색상
#                                   fill_color='#3186cc'      # 면 색상
#                                   )
#     marker.add_to(map_osm)

# map_osm
# Out:
# 0        33.251523
# 1        33.251523
# 2        33.251395
# 3        33.251395
# 4        33.249872
#            ...
# 26802    33.246478
# 26803    33.246478
# 26804    33.246822
# 26805    33.246822
# 26806    33.246822
# Name: 위도, Length: 26648, dtype: float64 0        126.559351
# 1        126.559351
# 2        126.559516
# 3        126.559516
# 4        126.559884
#             ...
# 26802    126.556058
# 26803    126.556058
# 26804    126.556491
# 26805    126.556491
# 26806    126.556491
# Name: 경도, Length: 26648, dtype: float64
# 0        33.251523
# 1        33.251523
# 2        33.251395
# 3        33.251395
# 4        33.249872
#            ...
# 26802    33.246478
# 26803    33.246478
# 26804    33.246822
# 26805    33.246822
# 26806    33.246822
# Name: 위도, Length: 26648, dtype: float64 0        126.559351
# 1        126.559351
# 2        126.559516
# 3        126.559516
# 4        126.559884
#             ...
# 26802    126.556058
# 26803    126.556058
# ...

# %%
wifi.to_csv("wifi_test.csv")
