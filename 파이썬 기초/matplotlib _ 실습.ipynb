# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.rc('font',family='Malgun Gothic')

# %%
x=[10, 14, 19, 20, 25]
plt.plot(x)
plt.show()
# Out:
# findfont: Font family ['MalgunGothic'] not found. Falling back to DejaVu Sans.

# %%
x=np.arange(-4.5, 5, 0.5)
y=x**2
plt.plot(x, y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = np.arange(-4.5, 5, 0.5)

y1 = x**2
y2 = x+30
y3 = x**2 +10

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

plt.show()

# %%
x = np.arange(-4.5, 5, 0.5)

y1=x**2
y2 = x+30
y3 = x**2 +10

plt.plot(x, y1, color='red', linestyle='dashed')
plt.plot(x, y2, 'b:')
plt.plot(x, y3, color='#00ff00', linestyle="-.")

plt.show()

# %%
x= np.linspace(0, 10, 100)
y=x**2
plt.plot(x, y, '--r')

# %%
x=np.linspace(0, 10, 100)
y1= x**2
y2 = x**3

plt.plot(x, y1, 'r', label="라인1")
plt.plot(x, y2, 'g', label="라인2")

plt.xlabel("x 라벨")
plt.ylabel("y 라벨")

plt.legend(loc=2)


plt.show()

# %%
plt.rc('font', family='Malgun Gothic')

# %%
plt.subplot(131)
plt.plot([1,2],color='r')

plt.subplot(132)
plt.plot([1,2],color='g')

plt.subplot(133)
plt.plot([1,2],color='b')

plt.show()

# %%
plt.subplot(221)
plt.plot([1,2],color='r')

plt.subplot(222)
plt.plot([1,2],color='g')

plt.subplot(223)
plt.plot([1,2],color='b')

plt.subplot(224)
plt.plot([1,2],color='r')

plt.show()

# %%
plt.rc('font',family='Malgun Gothic')

# %%
plt.figure(figsize=(5,5))
grid = plt.GridSpec(2,3)

plt.subplot(grid[0,0])
plt.plot([1,2],color='r')

plt.subplot(grid[0,1])
plt.plot([1,2],color='g')

plt.subplot(grid[0,2])
plt.plot([1,2],color='b')

plt.subplot(grid[1,:2])
plt.plot([1,2],color='b')

plt.subplot(grid[1,2])
plt.plot([1,2],color='r')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.rand(30)
y=np.random.rand(30)
a=np.random.rand(30)
b=np.random.rand(30)
e=np.random.rand(30)
f=np.random.rand(30)
color=np.random.rand(30)

size=100*np.random.rand(30)

plt.scatter(x, y, s=size, c=color, alpha=0.5, marker='o')
plt.scatter(a, b, s=size, c=color, alpha=0.5, marker='^')
plt.scatter(e, f, s=size, c=color, alpha=0.5, marker='+')
plt.show()

# %%
data = [np.random.randint(1,7) for i in range(10)]
plt.hist(data, bins=6, alpha=1)
plt.sh
# Out:
# (array([2., 2., 1., 1., 3., 1.]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]),
#  <BarContainer object of 6 artists>)

# %%
plt.bar(['10eo', '20대', '30대', '40대', '50대'], [np.random.randint(1,50) for i in range(5)])
plt.show()

# %%
plt.barh(['10eo', '20대', '30대', '40대', '50대'], [np.random.randint(1,50) for i in range(5)])
# Out:
# <BarContainer object of 5 artists>

# %%
plt.barh(['10eo', '20대', '30대', '40대', '50대'], [np.random.randint(1,50) for i in range(5)], color="g")
plt.title('제목')
plt.xlabel('나이')
plt.ylabel('값')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# %%
covid19 = pd.read_csv('kr_daily.csv', index_col="date")

# %%
covid19
# Out:
#           confirmed  death  released  candidate  negative
# date
# 20200121          1      0         0          0         0
# 20200122          1      0         0          0         0
# 20200123          1      0         0          0         0
# 20200124          2      0         0          0         0
# 20200125          2      0         0          0         0
# ...             ...    ...       ...        ...       ...
# 20200528      11344    269     10340     857322    834952
# 20200529      11402    269     10363     873718    849161
# 20200530      11441    269     10398     891460    865162
# 20200531      11468    270     10405     899354    876060
# 20200601      11503    271     10422     909888    885830
#
# [133 rows x 5 columns]

# %%
x=pd.date_range(start='2020-05-18', end='2020-06-01')
y=pd.to_datetime(['2020-05-18','2020-06-01'])
plt.title('확진자')
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-392dbb499d35> in <module>
#       2 y=pd.to_datetime(['2020-05-18','2020-06-01'])
#       3 plt.title('확진자')
# ----> 4 plt.plot(x, y)
#       5 plt.show()
#
# ~\anaconda3\envs\abangues\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~\anaconda3\envs\abangues\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\anaconda3\envs\abangues\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\anaconda3\envs\abangues\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (15,) and (2,)
