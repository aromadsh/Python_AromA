# %% [markdown]
# # 17. 함수
#
# ### 17.1 함수
# - 특정한 기능을 반복해서 사용해야할 때

# %%
def func(a,b):
    print("함수입니다.")
    return a + b

func_test = func(1,2)
print(func_test)
# Out:
# 함수입니다.
# 3

# %% [markdown]
# ###### 17.1.1 인자와 반환값이 없는 함수

# %%
def func():
    print("Hello, Function")
    
func()
# Out:
# Hello, Function

# %% [markdown]
# ###### 17.1.2 인자는 있으나 반환값이 없는 함수

# %%
def func(name):
    print("Hello, "+ name)

func("function")
# Out:
# Hello, function

# %% [markdown]
# ###### 17.1.3 인자와 반환값이 있는 함수

# %%
def func(a, b):
    return a + b

y = func(1,2)
print(y)
# Out:
# 3

# %% [markdown]
# ###### 17.1.4 값을 여러개 반환

# %%
def func(a, b):
    return a + b, a - b

y = func(1, 2)
print(y)
# Out:
# (3, -1)

# %% [markdown]
# ###### 17.1.5 반환값(return)은 함수의 종료를 위해 사용 되기도 한다.

# %%
def id_check(id):
    if id == "admin":
        print("invalid id : admin")
        return print
    print("valid id : ", id)
    
print(id_check('admin'))
print(id_check("ejf"))
# Out:
# invalid id : admin
# <built-in function print>
# valid id :  ejf
# None

# %% [markdown]
# ###### 17.1.6 여러 인자를 반환(튜플 사용)

# %%
def func(a):
    b = a + 1
    return a, b

print(func(10))
# Out:
# (10, 11)

# %%
def func(a):
    b = a + 1
    return a, b

a, b = func(10)
print(a, b)
# Out:
# 10 11

# %% [markdown]
# ### 17.2 변수의 유효 범위

# %%
a = 5 # 전역변수

def func1():
    a = 1 # 지역변수
    print(a)

func1()
print(a)
# Out:
# 1
# 5

# %%
a = 3 # 전역변수
def func2():
    print(a)
func2()
# Out:
# 3

# %%
a = 2 # 전역변수
def func3():
    global a # 전역변수 선언
    a = 1 # 전역변수 
    print(a)

func3()
print(a)
# Out:
# 1
# 1

# %% [markdown]
# ### 실습 01
# **리스트와 찾고싶은 값을 모두 입력하면 입력한 값의 인덱스(위치)를 리턴해주는 함수만들기**

# %%
list_ = [1, 2, 3, 1, 4, 2, 1]

def allindex(lis, x):
    index_x = []
    for idx,lis in enumerate(lis):
        if lis == x:
            index_x.append(idx)
    return index_x

allindex (list_, 1)
# Out:
# [0, 3, 6]

# %% [markdown]
# ### 17.3 함수응용
#
# ###### 17.3.1 인자값에 리스트 사용 (언패킹)

# %%
def func (a, b, c):
    print(a, b, c)

x = [1, 2, 3]
func(*x)
# Out:
# 1 2 3

# %% [markdown]
# ###### 17.3.2 가변인수

# %%
def func(*args):
    for arg in args:
        print(arg)
func(1)
func(1, 2, 3, 4, 5)
# Out:
# 1
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ###### 17.3.3 가변인수와 고정인수 같이사용

# %%
def func(a, *args):
    print(a, end="")
    for arg in args:
        print(arg, end=" ")
func(100, 1, 2, 3, 4, 5)
# Out:
# 1001 2 3 4 5

# %% [markdown]
# ###### 17.3.4 키워드 인수 & 딕셔너리 언패킹

# %%
def func(email, name):
    print("이메일 : ", email)
    print("이름 : ", name)

func(email = "aa@aa.com", name="tom")

x = {"email":"aa@aa.com", "name":"tom"}
func(**x)
# Out:
# 이메일 :  aa@aa.com
# 이름 :  tom
# 이메일 :  aa@aa.com
# 이름 :  tom

# %% [markdown]
# ###### 17.3.5 가변 키워드 인수

# %%
def func(**kwargs):
    print("이메일 : ", kwargs['email'])
    print("이름 : ", kwargs['name'])
    
func(email="aa@aa.com", name="tom")
# Out:
# 이메일 :  aa@aa.com
# 이름 :  tom

# %% [markdown]
# ###### 17.3.6 매개변수 초기값

# %%
def func(email, name, age=20):
    print("이메일 : ", email)
    print("이름 : ", name)
    print("나이 : ", age)
    
func(email="aa.aa.com", name="tom")
func(email="aa.aa.com", name="tom", age=18)
# Out:
# 이메일 :  aa.aa.com
# 이름 :  tom
# 나이 :  20
# 이메일 :  aa.aa.com
# 이름 :  tom
# 나이 :  18

# %% [markdown]
# ### 실습 02
# **가변인수와 고정인수를 사용해 모든 값을 더하거나 곱하는 함수 작성**

# %%
def calc(x, *args):
    if x == "+":
        sum = 0
        for i in args:
            sum += i
        return sum
    
    elif x == "*":
        mul = 1
        for i in args:
            mul *= i
        return mul

print(calc("+", 1, 2, 3, 4, 5))
print(calc("*", 1, 2, 3, 4, 5))
# Out:
# 15
# 120

# %% [markdown]
# ### 17.4 재귀함수
# ###### 17.4.1 함수 안에서 자기자신을 호출하는 방식

# %%
def test():
    print('재귀함수!')
    test()
test()
# 재귀함수! 가 계속 출력되다가 재귀의 깊이가 일정길이를 초과하면 오류
# Out:
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# ...

# %% [markdown]
# ###### 17.4.2 재귀함수 종료조건

# %%
def test(end):
    if end == 0:
        return
    print("재귀함수!")
    end -= 1
    test(end)
    
test(5)
# Out:
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!
# 재귀함수!

# %% [markdown]
# ###### 17.4.3 재귀호출로 팩토리얼 구하기

# %%
def factorial(n):
    if n == 1:
        return 1
    return n * factorial(n-1)

factorial(5)
# Out:
# 120

# %% [markdown]
# ### 실습 03
# **1. 양의정수**

# %%
def factorizl(n):
    if
# Out:
# 30

# %%
a=[1,2,3,4,5,6,7,8,9]

def f(x):
    if x %2 ==0:
        return 0
    else :
        return x

# %%
temp = []
for item in a:
    temp.append(f(item))
    
temp
# Out:
# [1, 0, 3, 0, 5, 0, 7, 0, 9]

# %%
list(map(f,a))
# Out:
# [1, 0, 3, 0, 5, 0, 7, 0, 9]

# %%
list(map(lambda x: 0 if x %2 == 0 else x, a))
# Out:
# [1, 0, 3, 0, 5, 0, 7, 0, 9]

# %%
a=[2,6,4,3,6,8,3,9,6]

# %%
temp=[]
for item in a: 
    if item >2 and item <8:
        temp.append(item)
temp
# Out:
# [6, 4, 3, 6, 3, 6]

# %%
def f(x) :
    if item >2 and item <8:
        return x

# %%
list(filter(f,a))
# Out:
# [2, 6, 4, 3, 6, 8, 3, 9, 6]

# %%
list(filter(lambda x : x>2 and x<8, a))
# Out:
# [6, 4, 3, 6, 3, 6]

# %%
numbers = [12, 32, 55, 12, 32, 4, 86, 50]

# %%
list(map(lambda x : "합격" if x > 60 else "대기" if 50 < x <= 60 else "불합격" ,numbers))
# Out:
# ['불합격', '불합격', '대기', '불합격', '불합격', '불합격', '합격', '불합격']

# %%
files = ["memo.txt","1.jpg","32.png","23.jpg","223.jpg"]

# %%
temp = []
for i in range(len(files)):
    index = files[i].find("jpg")
    if index >=0 :
        temp.append(files[i])
        
print(temp)
# Out:
# ['1.jpg', '23.jpg', '223.jpg']

# %%
def search(x):
    index =x.find("jpg")
    if index >= 1:
        return x

# %%
result = []
for file in files:
    result.append (search(file))
result
# Out:
# [None, '1.jpg', None, '23.jpg', '223.jpg']

# %%
files = ["memo.txt","1.jpg","32.png","23.jpg","223.jpg"]

# %%
list(filter(lambda x : x.find("jpg") >= 0,files))
# Out:
# ['1.jpg', '23.jpg', '223.jpg']

# %%
print('a')
print('a')
print('a')
print('a')
try :
    print(10/0)
except Exception as e:
    print("예외 오류 사항",e)

print('a')
print('a')
print('a')
print('a')
print('a')
# Out:
# a
# a
# a
# a
# 예외 오류 사항 division by zero
# a
# a
# a
# a
# a

# %%
x=[1,2,3]

try : 
#     print(10/0)
    x[5]
except ZeroDivisionError as e:
    print("잘못된 숫자",e)
except IndexError as e:
    print("wkfah",e)
# Out:
# wkfah list index out of range
