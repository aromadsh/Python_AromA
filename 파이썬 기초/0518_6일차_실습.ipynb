# %%
import pandas as pd
import numpy as np

# %%
pd.date_range(start='2019-01-01', end='2019-01-07')
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='01/01/2019', end='01/07/2019')
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2019-01-01', periods=7)
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2019-01-01', periods=7, freq='2D')
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-03', '2019-01-05', '2019-01-07',
#                '2019-01-09', '2019-01-11', '2019-01-13'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range(start='2019-01-01', periods=7, freq='W')
# Out:
# DatetimeIndex(['2019-01-06', '2019-01-13', '2019-01-20', '2019-01-27',
#                '2019-02-03', '2019-02-10', '2019-02-17'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
x = pd.to_datetime(['2020-01-02 03:45', '2021-12-24 23:59'])
print(x)
# Out:
# DatetimeIndex(['2020-01-02 03:45:00', '2021-12-24 23:59:00'], dtype='datetime64[ns]', freq=None)

# %%
x.year
# Out:
# Int64Index([2020, 2021], dtype='int64')

# %%
x.weekday
# Out:
# Int64Index([3, 4], dtype='int64')

# %%
diff = x - pd.to_datetime('2021-05-18 09:25')
diff
# Out:
# TimedeltaIndex(['-503 days +18:20:00', '220 days 14:34:00'], dtype='timedelta64[ns]', freq=None)

# %%
a = pd.Series([103, 500000, 370000], ['판매량', '매출', '순이익'])
b = pd.Series([70, 300000, 80000], ['판매량', '매출', '세금환급'])
c = pd.Series([130, 400000, 190000], ['판매량', '매출', '순이익'])

# %%
df = pd.DataFrame([a, b, c], index=[2015, 2016, 2017])
df
# Out:
#         판매량        매출       순이익     세금환급
# 2015  103.0  500000.0  370000.0      NaN
# 2016   70.0  300000.0       NaN  80000.0
# 2017  130.0  400000.0  190000.0      NaN

# %%
df['판매량']
# Out:
# 2015    103.0
# 2016     70.0
# 2017    130.0
# Name: 판매량, dtype: float64

# %%
type(df['판매량'])
# Out:
# pandas.core.series.Series

# %%
df[['판매량', '매출']]
# Out:
#         판매량        매출
# 2015  103.0  500000.0
# 2016   70.0  300000.0
# 2017  130.0  400000.0

# %%
type(df[['판매량', '매출']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[1:3]
# Out:
#         판매량        매출       순이익     세금환급
# 2016   70.0  300000.0       NaN  80000.0
# 2017  130.0  400000.0  190000.0      NaN

# %%
df.iloc[1]
# Out:
# 판매량         70.0
# 매출      300000.0
# 순이익          NaN
# 세금환급     80000.0
# Name: 2016, dtype: float64

# %%
df.loc[2016]
# Out:
# 판매량         70.0
# 매출      300000.0
# 순이익          NaN
# 세금환급     80000.0
# Name: 2016, dtype: float64

# %%
df.iloc[[0,2]]
# Out:
#         판매량        매출       순이익  세금환급
# 2015  103.0  500000.0  370000.0   NaN
# 2017  130.0  400000.0  190000.0   NaN

# %%
df.loc[[2015, 2017]]
# Out:
#         판매량        매출       순이익  세금환급
# 2015  103.0  500000.0  370000.0   NaN
# 2017  130.0  400000.0  190000.0   NaN

# %%
df.iloc[[0,2],[0,2]]
# Out:
#         판매량       순이익
# 2015  103.0  370000.0
# 2017  130.0  190000.0

# %%
df.loc[[2015,2017],['판매량','순이익']]
# Out:
#         판매량       순이익
# 2015  103.0  370000.0
# 2017  130.0  190000.0

# %%
pd.DataFrame(sales_data, columns=['판매량','매출','순이익'], index=df.index
# Out:
#   File "<ipython-input-41-c72cf03532a1>", line 1
#     pd.DataFrame(sales_data, columns=['판매량','매출','순이익'], index=df.index
#                                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
sales_data = {
 '연도':[2015, 2016, 2017, 2018, 2019, 2020],
 '판매량':[103, 70, 130, 160, 190, 230],
 '매출':[500000, 300000, 400000, 550000, 700000, 680000],
 '순이익':[370000, 190000, 300000, 480000, 600000, 590000]}

# %%
sales_data=pd.read_csv("sales_data.csv", index_col='연도', encoding='utf-8')
sales_data
# Out:
#       판매량      매출      순익
# 연도
# 2015  103  500000  370000
# 2016   70  300000  190000
# 2017  130  400000  300000
# 2018   60  550000  480000
# 2019  190  700000  600000
# 2020  230  680000  590000

# %%
sales_data=pd.read_csv("sales_data.csv", index_col='연도', encoding='utf-8', usecols=['연도','판매량','매출' ])
sales_data
# Out:
#       판매량      매출
# 연도
# 2015  103  500000
# 2016   70  300000
# 2017  130  400000
# 2018   60  550000
# 2019  190  700000
# 2020  230  680000

# %%
sales_data['순이익률'] = (sales_data['순익']/sales_data['매출'])*100

# %%
sales_data
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률
# 연도
# 2015  103  500000  370000   103    NaN  74.000000
# 2016   70  300000  190000    70  120.0  63.333333
# 2017  130  400000  300000   130    NaN  75.000000
# 2018   60  550000  480000    60  110.0  87.272727
# 2019  190  700000  600000   190    NaN  85.714286
# 2020  230  680000  590000     0    NaN  86.764706

# %%
def check(x) :
    if x > 80:
        return '높음'
    else :
        return '낮음'

# %%
sales_data['순이익율 비교'] = sales_data['순이익률'].apply(check)
sales_data
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률 순이익율 비교
# 연도
# 2015  103  500000  370000   103    NaN  74.000000      낮음
# 2016   70  300000  190000    70  120.0  63.333333      낮음
# 2017  130  400000  300000   130    NaN  75.000000      낮음
# 2018   60  550000  480000    60  110.0  87.272727      높음
# 2019  190  700000  600000   190    NaN  85.714286      높음
# 2020  230  680000  590000     0    NaN  86.764706      높음

# %%
del sales_data['순이익율 비교']
sales_data
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률
# 연도
# 2015  103  500000  370000   103    NaN  74.000000
# 2016   70  300000  190000    70  120.0  63.333333
# 2017  130  400000  300000   130    NaN  75.000000
# 2018   60  550000  480000    60  110.0  87.272727
# 2019  190  700000  600000   190    NaN  85.714286
# 2020  230  680000  590000     0    NaN  86.764706

# %%
sales_data['순이익율 비교']=sales_data['순이익률'].apply(lambda x : "높음" if x > 80  else "낮음" )

# %%
sales_data[sales_data['매출'] > 300000]
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률 순이익율 비교
# 연도
# 2015  103  500000  370000   103    NaN  74.000000      낮음
# 2017  130  400000  300000   130    NaN  75.000000      낮음
# 2018   60  550000  480000    60  110.0  87.272727      높음
# 2019  190  700000  600000   190    NaN  85.714286      높음
# 2020  230  680000  590000     0    NaN  86.764706      높음

# %%
sales_data['테스트1']=np.where(sales_data['판매량'] > 200, 0, sales_data['판매량'])
sales_data
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률 순이익율 비교
# 연도
# 2015  103  500000  370000   103    NaN  74.000000      낮음
# 2016   70  300000  190000    70  120.0  63.333333      낮음
# 2017  130  400000  300000   130    NaN  75.000000      낮음
# 2018   60  550000  480000    60  110.0  87.272727      높음
# 2019  190  700000  600000   190    NaN  85.714286      높음
# 2020  230  680000  590000     0    NaN  86.764706      높음

# %%
sales_data['테스트2']=sales_data[sales_data['판매량'] < 100]['판매량']+50
sales_data
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률 순이익율 비교
# 연도
# 2015  103  500000  370000   103    NaN  74.000000      낮음
# 2016   70  300000  190000    70  120.0  63.333333      낮음
# 2017  130  400000  300000   130    NaN  75.000000      낮음
# 2018   60  550000  480000    60  110.0  87.272727      높음
# 2019  190  700000  600000   190    NaN  85.714286      높음
# 2020  230  680000  590000     0    NaN  86.764706      높음

# %%
sales_data.drop(['순이익율 비교'], axis=1, inplace=True)

# %%
sales_data
# Out:
#       판매량      매출      순익  테스트1   테스트2       순이익률
# 연도
# 2015  103  500000  370000   103    NaN  74.000000
# 2016   70  300000  190000    70  120.0  63.333333
# 2017  130  400000  300000   130    NaN  75.000000
# 2018   60  550000  480000    60  110.0  87.272727
# 2019  190  700000  600000   190    NaN  85.714286
# 2020  230  680000  590000     0    NaN  86.764706

# %%
sales_data.loc[6] = [2021, 360, 720000, 650000, 0, 0, 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-53bc793a64df> in <module>
# ----> 1 sales_data.iloc[6] = [2021, 360, 720000, 650000, 0, 0, 0]
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1753                     if len(ilocs) != len(value):
#    1754                         raise ValueError(
# -> 1755                             "Must have equal len keys and value "
#    1756                             "when setting with an iterable"
#    1757                         )
#
# ...

# %%
sales_data.loc[6] = [2021, 360, 720000, 650000, 0, 0, 0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-1697de7043c0> in <module>
# ----> 1 sales_data.loc[6] = [2021, 360, 720000, 650000, 0, 0, 0]
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1753                     if len(ilocs) != len(value):
#    1754                         raise ValueError(
# -> 1755                             "Must have equal len keys and value "
#    1756                             "when setting with an iterable"
#    1757                         )
#
# ...

# %% [markdown]
# ### 데이터 병합

# %%
sales_data1 = {
 '연도':[2015, 2016, 2017, 2018],
 '판매량':[103, 70, 130, 160],
 '매출':[500000, 300000, 400000, 550000],
 '순이익':[370000, 190000, 300000, 480000]
 }

# %%
sales_data2 = {
 '연도':[2019, 2020],
 '판매량':[190, 230],
 '매출':[700000, 680000],
 '순이익':[ 600000, 590000]
}

# %%
sales_data1 = pd.DataFrame(sales_data1)
print(sales_data1)

sales_data2 = pd.DataFrame(sales_data2)
print(sales_data2)

cost_data = pd.DataFrame(cost_data)
print(cost_data)
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
#      연도  판매량      매출     순이익
# 0  2019  190  700000  600000
# 1  2020  230  680000  590000
#      연도    이자  관리비     세금
# 0  2015  1520  650  12000
# 1  2016  1120  400   8900
# 2  2017  1360  750  10900
# 3  2018  1680  800  12800

# %%
cost_data = {
 '연도':[2015, 2016, 2017, 2018],
 '이자':[1520, 1120, 1360, 1680],
 '관리비':[650, 400, 750, 800],
 '세금':[12000, 8900, 10900, 12800] }

# %%
pd.concat([sales_data1, sales_data2], ignore_index=True)
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
sales_data1.append(sales_data2, ignore_index=True)
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
sales_df=sales_data1.append(sales_data2, ignore_index=True)

# %%
pd.merge(sales_df, cost_data, on='연도', how='')
# Out:
#      연도    판매량        매출       순이익    이자  관리비     세금
# 0  2015  103.0  500000.0  370000.0  1520  650  12000
# 1  2016    NaN       NaN       NaN  1120  400   8900
# 2  2018  160.0  550000.0  480000.0  1680  800  12800

# %%
cost_data.drop([2], inplace=True)
cost_data
# Out:
#      연도    이자  관리비     세금
# 0  2015  1520  650  12000
# 1  2016  1120  400   8900
# 3  2018  1680  800  12800

# %%
sales_df.drop([1], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-142-49f7ee239fa2> in <module>
# ----> 1 sales_df.drop([1], inplace=True)
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
sales_df
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
sales_df["테스트1"] = 'test1'
sales_df["테스트2"] = 'test2'
sales_df["테스트3"] = 'test3'
sales_df
# Out:
#      연도  판매량      매출     순이익   테스트1   테스트2   테스트3
# 0  2015  103  500000  370000  test1  test2  test3
# 2  2017  130  400000  300000  test1  test2  test3
# 3  2018  160  550000  480000  test1  test2  test3
# 4  2019  190  700000  600000  test1  test2  test3
# 5  2020  230  680000  590000  test1  test2  test3

# %%
del sales_df["테스트1"]
sales_df
# Out:
#      연도  판매량      매출     순이익   테스트2   테스트3
# 0  2015  103  500000  370000  test2  test3
# 2  2017  130  400000  300000  test2  test3
# 3  2018  160  550000  480000  test2  test3
# 4  2019  190  700000  600000  test2  test3
# 5  2020  230  680000  590000  test2  test3

# %%
print(sales_df.drop(["테스트2", "테스트3"], axis='columns', inplace=True))
print(sales_df)
# Out:
# None
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
sales_df["테스트1"] = 'test1'
sales_df["테스트2"] = 'test2'
sales_df["테스트3"] = 'test3'

# %%
sales_df.drop(sales_df.columns[[0,2]], axis=1)
# Out:
#    판매량     순이익   테스트1   테스트2   테스트3
# 0  103  370000  test1  test2  test3
# 2  130  300000  test1  test2  test3
# 3  160  480000  test1  test2  test3
# 4  190  600000  test1  test2  test3
# 5  230  590000  test1  test2  test3

# %%
sales_df.drop(0, inplace=True)
sales_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-159-124efa5b8890> in <module>
# ----> 1 sales_df.drop(0, inplace=True)
#       2 sales_df
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~\anaconda3\envs\abangues\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
sales_df.drop([2, 3, 5])
# Out:
#      연도  판매량      매출     순이익   테스트1   테스트2   테스트3
# 4  2019  190  700000  600000  test1  test2  test3

# %%
df = pd.DataFrame(np.random.randint(1, 100, size=(4, 4)), index=[['A','A','B','B'],['a','b','a','b']], 
 
columns=[['가가','가가','나나','나나'],['가','나','가','나']])

df
# Out:
#      가가      나나
#       가   나   가   나
# A a  74  90  93  88
#   b  59   6  86  71
# B a  70  10  39  67
#   b  40   7  34  94

# %%
df['가가']
# Out:
#       가   나
# A a  74  90
#   b  59   6
# B a  70  10
#   b  40   7

# %%
df.loc['A']
# Out:
#    가가      나나
#     가   나   가   나
# a  74  90  93  88
# b  59   6  86  71

# %%
df = pd.DataFrame(np.random.randint(1, 100, size=(8, 2)), index=[['A창고','A창고','A창고','A창고','B창고','B창고','B창고','B창고'], ['사과','배','바나나','사과','사과','배','바나나','배']],
columns=['판매','재고'])
df
# Out:
#          판매  재고
# A창고 사과    9  14
#     배    85  94
#     바나나  59  26
#     사과   76  28
# B창고 사과   44  53
#     배    22  22
#     바나나  41  81
#     배    57  15

# %%
df.index.names = ['창고명','상품명']

# %%
df.index
# Out:
# MultiIndex([('A창고',  '사과'),
#             ('A창고',   '배'),
#             ('A창고', '바나나'),
#             ('A창고',  '사과'),
#             ('B창고',  '사과'),
#             ('B창고',   '배'),
#             ('B창고', '바나나'),
#             ('B창고',   '배')],
#            names=['창고명', '상품명'])

# %%
df.groupby('창고명').sum()
# Out:
#       판매   재고
# 창고명
# A창고  229  162
# B창고  164  171

# %%
df.groupby('상품명').sum()
# Out:
#       판매   재고
# 상품명
# 바나나  100  107
# 배    164  131
# 사과   129   95

# %%
df.groupby(['창고명','상품명']).sum()
# Out:
#          판매  재고
# 창고명 상품명
# A창고 바나나  59  26
#     배    85  94
#     사과   85  42
# B창고 바나나  41  81
#     배    79  37
#     사과   44  53

# %%
df
# Out:
#          판매  재고
# 창고명 상품명
# A창고 사과    9  14
#     배    85  94
#     바나나  59  26
#     사과   76  28
# B창고 사과   44  53
#     배    22  22
#     바나나  41  81
#     배    57  15

# %%
df.sort_values(by="판매", ascending=True)
# Out:
#          판매  재고
# 창고명 상품명
# A창고 사과    9  14
# B창고 배    22  22
#     바나나  41  81
#     사과   44  53
#     배    57  15
# A창고 바나나  59  26
#     사과   76  28
#     배    85  94

# %%
df.sort_values(by=["판매","재고"], ascending=[True, True])
# Out:
#          판매  재고
# 창고명 상품명
# A창고 사과    9  14
# B창고 배    22  22
#     바나나  41  81
#     사과   44  53
#     배    57  15
# A창고 바나나  59  26
#     사과   76  28
#     배    85  94

# %%
school = pd.DataFrame(np.random.randint(1, 100, size=(15, 3)), index=[['1학년','1학년','1학년','1학년','1학년','2학년','2학년','2학년','2학년','2학년','3학년','3학년','3학년','3학년','3학년'], ['1반','2반','3반','4반','5반','1반','2반','3반','4반','5반','1반','2반','3반','4반','5반']],
columns=['국어','영어','과학'])
df
# Out:
#         국어  영어  과학
# 1학년 1반  27  79  73
#     2반  91  11  75
#     3반  66  43  50
#     4반  58  80  24
#     5반  92  97  68
# 2학년 1반  95  90  53
#     2반  95  80  81
#     3반  92  36  22
#     4반  60  51   3
#     5반  65  23   3
# 3학년 1반  27  73  99
#     2반  29  28  73
#     3반  21  49  33
#     4반  53  75  41
#     5반  78  29  20

# %%
school['총점'] = school['국어']+school['영어']+school['과학']

# %%
school["평균"] = (school['국어']+school['영어']+school['과학'])//3

# %%
school
# Out:
#         국어  영어  과학   총점  평균
# 1학년 1반  50  46   8  104  34
#     2반  45  18  47  110  36
#     3반  70  71  29  170  56
#     4반  22  15  21   58  19
#     5반  43   2  10   55  18
# 2학년 1반  75  47  85  207  69
#     2반  64  88  14  166  55
#     3반  23  13  70  106  35
#     4반  45   9  44   98  32
#     5반  45  80  82  207  69
# 3학년 1반   6  72  84  162  54
#     2반  17  44  99  160  53
#     3반  44  45  72  161  53
#     4반  18  73  20  111  37
#     5반  81   4  20  105  35

# %%
school.index.names = ['학년', '반']
school.groupby('학년').sum()
# Out:
#       국어   영어   과학   총점   평균
# 학년
# 1학년  230  152  115  497  163
# 2학년  252  237  295  784  260
# 3학년  166  238  295  699  232
