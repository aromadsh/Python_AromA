# %%
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from io import open
from urllib.request import urlopen
import re
import os

# %%
def read_pdf_file(pdfFile):
    pdfrm = PDFResourceManager()
    strio = StringIO()
    lapa = LAParams()
    device = TextConverter(pdfrm, strio, laparams = lapa)
    
    process_pdf(pdfrm, device, pdfFile)
    device.close()
    
    content = strio.getvalue()
    strio.close()
    return content

# %%
new_ESG_standard = open("standard/신ESG모범규준.pdf", "rb")
ESG_standard = read_pdf_file(new_ESG_standard)
new_ESG_standard.close()
# Out:
# WARNING:root:Cannot locate objid=444
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 38
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 52
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 40
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 51318
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 51810
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 48042
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 54990
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 22
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 20
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 22
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 21
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 18
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 47
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 37
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 39
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 52
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 37
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 56
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 37
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 50
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 39
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 55
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 54
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 58
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 45
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 39
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 38
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 52
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 40
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 51318
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 51810
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 48042
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPHIN+NotoSansCJKkr-Bold', cidcoding='Adobe-Identity'>, 54990
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 14240
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 15676
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 14688
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 15493
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 11125
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 19056
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 9200
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 15472
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 15836
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 10012
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 12140
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 12000
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 27
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 26
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 16
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 13180
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 9092
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 24
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 17593
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 12
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 15472
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 15836
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 10824
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 10845
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 16
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 19424
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 9201
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 8948
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 11804
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 14352
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 13
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 56
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 48
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 2202
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 20
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 22
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 23
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 27
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 27
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 25
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 23
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 23
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 23
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 29
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 42
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 37
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 60
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 2202
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 20
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 22
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 23
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 27
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 27
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 25
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 17
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 22
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 26
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 23
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 20
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 44
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 51
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 49
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 52
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 37
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 43
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 41
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGPA+KoPubWorldDotumBold-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 2202
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 91
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 91
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 91
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 18
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 71
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 75
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 87
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 18
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 83
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 18
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 79
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 86
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='HFPGNA+KoPubWorldDotumLight-KSCms-UHC-H', cidcoding='Adobe-Identity'>, 4

# %%
from konlpy.tag import Mecab
mecab = Mecab()

tokens = []
def word_token (x) :
    for token in mecab.pos(x):
        tokens.append(token)
    return tokens

word_token(ESG_standard)
# Out:
# [('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('47', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('51', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('54', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('41', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('37', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('4', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('39', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('51', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('54', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('52', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('51', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('54', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('37', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('56', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('41', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('4', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('43', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('51', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('58', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('41', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('54', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('50', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('37', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('50', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('39', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('41', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('4', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('55', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('41', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('54', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('58', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('45', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('39', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('41', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('38', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('52', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('40', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('51318', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('51810', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('48042', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('54990', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('22', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('20', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('22', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('21', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('18', 'SN'),
#  (')', 'SSC'),
#  ('(', 'SSO'),
#  ('cid', 'SL'),
#  (':', 'SC'),
#  ('4', 'SN'),
#  (')', 'SSC'),
#  ('8', 'SN'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('CONTENTS', 'SL'),
#  ('CONTENTS', 'SL'),
#  ('01', 'SN'),
#  ('┃', 'SY'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('➊', 'SY'),
#  ('전문', 'NNG'),
#  ('➋', 'SY'),
#  ('리더십', 'NNG'),
#  ('과', 'JC'),
#  ('거버넌스', 'NNP'),
#  ('➌', 'SY'),
#  ('위험', 'NNG'),
#  ('관리', 'NNG'),
#  ('➍', 'SY'),
#  ('운영', 'NNG'),
#  ('및', 'MAJ'),
#  ('성과', 'NNG'),
#  ('➎', 'SY'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('소통', 'NNG'),
#  ('➏', 'SY'),
#  ('부록', 'NNG'),
#  ('➐', 'SY'),
#  ('참고', 'NNG'),
#  ('문헌', 'NNG'),
#  ('02', 'SN'),
#  ('┃', 'SY'),
#  ('사회', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('➊', 'SY'),
#  ('전문', 'NNG'),
#  ('➋', 'SY'),
#  ('리더십', 'NNG'),
#  ('과', 'JC'),
#  ('거버넌스', 'NNP'),
#  ('➌', 'SY'),
#  ('비', 'XPN'),
#  ('재무', 'NNG'),
#  ('위험', 'NNG'),
#  ('관리', 'NNG'),
#  ('➍', 'SY'),
#  ('운영', 'NNG'),
#  ('및', 'MAJ'),
#  ('성과', 'NNG'),
#  ('➎', 'SY'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('소통', 'NNG'),
#  ('➏', 'SY'),
#  ('부록', 'NNG'),
#  ('➐', 'SY'),
#  ('참고', 'NNG'),
#  ('문헌', 'NNG'),
#  ('03', 'SN'),
#  ('┃', 'SY'),
#  ('지배', 'NNG'),
#  ('구조', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('➊', 'SY'),
#  ('전문', 'NNG'),
#  ('➋', 'SY'),
#  ('이', 'MM'),
#  ('사회', 'NNG'),
#  ('리더십', 'NNG'),
#  ('➌', 'SY'),
#  ('주주', 'NNG'),
#  ('권', 'XSN'),
#  ('보호', 'NNG'),
#  ('➍', 'SY'),
#  ('감사', 'NNG'),
#  ('➎', 'SY'),
#  ('주주', 'NNG'),
#  ('및', 'MAJ'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('와', 'JKB'),
#  ('의', 'JKG'),
#  ('소통', 'NNG'),
#  ('➏', 'SY'),
#  ('참고', 'NNG'),
#  ('문헌', 'NNG'),
#  ('6', 'SN'),
#  ('8', 'SN'),
#  ('13', 'SN'),
#  ('18', 'SN'),
#  ('30', 'SN'),
#  ('33', 'SN'),
#  ('37', 'SN'),
#  ('40', 'SN'),
#  ('42', 'SN'),
#  ('47', 'SN'),
#  ('51', 'SN'),
#  ('63', 'SN'),
#  ('65', 'SN'),
#  ('76', 'SN'),
#  ('80', 'SN'),
#  ('83', 'SN'),
#  ('97', 'SN'),
#  ('102', 'SN'),
#  ('109', 'SN'),
#  ('114', 'SN'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('➊', 'SY'),
#  ('전문', 'NNG'),
#  ('➋', 'SY'),
#  ('리더십', 'NNG'),
#  ('과', 'JC'),
#  ('거버넌스', 'NNP'),
#  ('➌', 'SY'),
#  ('위험', 'NNG'),
#  ('관리', 'NNG'),
#  ('➍', 'SY'),
#  ('운영', 'NNG'),
#  ('및', 'MAJ'),
#  ('성과', 'NNG'),
#  ('➎', 'SY'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('소통', 'NNG'),
#  ('➏', 'SY'),
#  ('부록', 'NNG'),
#  ('➐', 'SY'),
#  ('참고', 'NNG'),
#  ('문헌', 'NNG'),
#  ('6', 'SN'),
#  ('8', 'SN'),
#  ('13', 'SN'),
#  ('18', 'SN'),
#  ('30', 'SN'),
#  ('33', 'SN'),
#  ('37', 'SN'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('KOREA', 'SL'),
#  ('CORPORATE', 'SL'),
#  ('GOVERNANCE', 'SL'),
#  ('SERVICE', 'SL'),
#  ('➊', 'SY'),
#  ('전문', 'NNG'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('의', 'JKG'),
#  ('제정', 'NNG'),
#  ('배경', 'NNG'),
#  ('기업', 'NNG'),
#  ('경영', 'NNG'),
#  ('에', 'JKB'),
#  ('있', 'VV'),
#  ('어', 'EC'),
#  ('환경', 'NNG'),
#  ('문제', 'NNG'),
#  ('가', 'JKS'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('발전', 'NNG'),
#  ('에', 'JKB'),
#  ('중요', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('영향', 'NNG'),
#  ('을', 'JKO'),
#  ('미치', 'VV'),
#  ('는', 'ETM'),
#  ('변수', 'NNG'),
#  ('로', 'JKB'),
#  ('부각', 'NNG'),
#  ('됨', 'XSV+ETN'),
#  ('에', 'JKB'),
#  ('따라', 'VV+EC'),
#  ('국내', 'NNG'),
#  ('기업', 'NNG'),
#  ('도', 'JX'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('을', 'JKO'),
#  ('통해', 'VV+EC'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('성', 'XSN'),
#  ('과', 'JC'),
#  ('수익', 'NNG'),
#  ('성', 'XSN'),
#  ('을', 'JKO'),
#  ('동시', 'NNG'),
#  ('에', 'JKB'),
#  ('고려', 'NNG'),
#  ('하', 'XSV'),
#  ('려는', 'ETM'),
#  ('세계', 'NNG'),
#  ('적', 'XSN'),
#  ('흐름', 'NNG'),
#  ('에', 'JKB'),
#  ('적극', 'NNG'),
#  ('적', 'XSN'),
#  ('이', 'VCP'),
#  ('고', 'EC'),
#  ('능동', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('대처', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('필요', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('특히', 'MAG'),
#  ('환경', 'NNG'),
#  ('의', 'JKG'),
#  ('질', 'NNG'),
#  ('을', 'JKO'),
#  ('개선', 'NNG'),
#  ('하', 'XSV'),
#  ('려는', 'ETM'),
#  ('활동', 'NNG'),
#  ('에', 'JKB'),
#  ('대한', 'VV+ETM'),
#  ('관심', 'NNG'),
#  ('이', 'JKS'),
#  ('지속', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('증대', 'NNG'),
#  ('됨', 'XSV+ETN'),
#  ('에', 'JKB'),
#  ('따라', 'VV+EC'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('경영', 'NNG'),
#  ('활동', 'NNG'),
#  ('이', 'JKS'),
#  ('환경', 'NNG'),
#  ('에', 'JKB'),
#  ('미치', 'VV'),
#  ('는', 'ETM'),
#  ('영향', 'NNG'),
#  ('은', 'JX'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('생존', 'NNG'),
#  ('가능', 'NNG'),
#  ('성', 'XSN'),
#  ('과', 'JC'),
#  ('경쟁력', 'NNG'),
#  ('에', 'JKB'),
#  ('중요', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('요소', 'NNG'),
#  ('가', 'JKS'),
#  ('되', 'VV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('이러', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('시대', 'NNG'),
#  ('적', 'XSN'),
#  ('요청', 'NNG'),
#  ('에', 'JKB'),
#  ('부응', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'EC'),
#  ('국내', 'NNG'),
#  ('기업', 'NNG'),
#  ('들', 'XSN'),
#  ('은', 'JX'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('을', 'JKO'),
#  ('수행', 'NNG'),
#  ('하', 'XSV'),
#  ('기', 'ETN'),
#  ('위해', 'VV+EC'),
#  ('지속', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('노력', 'NNG'),
#  ('하', 'XSV'),
#  ('여야', 'EC'),
#  ('하', 'VV'),
#  ('며', 'EC'),
#  (',', 'SC'),
#  ('주주', 'NNG'),
#  ('를', 'JKO'),
#  ('포함', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('다양', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('들', 'XSN'),
#  ('의', 'JKG'),
#  ('신뢰', 'NNG'),
#  ('를', 'JKO'),
#  ('얻', 'VV'),
#  ('기', 'ETN'),
#  ('위하', 'VV'),
#  ('여', 'EC'),
#  ('체계', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('을', 'JKO'),
#  ('수행', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('도록', 'EC'),
#  ('경영', 'NNG'),
#  ('체제', 'NNG'),
#  ('를', 'JKO'),
#  ('구축', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('필요', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('아울러', 'MAG'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('장기', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('발전', 'NNG'),
#  ('을', 'JKO'),
#  ('위해', 'VV+EC'),
#  ('기업', 'NNG'),
#  ('과', 'JC'),
#  ('그', 'MM'),
#  ('구성원', 'NNG'),
#  ('은', 'JX'),
#  ('투철', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('의식', 'NNG'),
#  ('을', 'JKO'),
#  ('가져야', 'VV+EC'),
#  ('할', 'VX+ETM'),
#  ('것', 'NNB'),
#  ('이', 'VCP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('의', 'JKG'),
#  ('제정', 'NNG'),
#  ('목적', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('은', 'JX'),
#  ('미래', 'NNG'),
#  ('지향', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('관점', 'NNG'),
#  ('에서', 'JKB'),
#  ('국내', 'NNG'),
#  ('기업', 'NNG'),
#  ('들', 'XSN'),
#  ('이', 'JKS'),
#  ('대내외', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('신뢰', 'NNG'),
#  ('받', 'VV'),
#  ('을', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('바람직', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('의', 'JKG'),
#  ('방향', 'NNG'),
#  ('을', 'JKO'),
#  ('제시', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'EC'),
#  ('관련', 'NNG'),
#  ('활동', 'NNG'),
#  ('수행', 'NNG'),
#  ('에', 'JKB'),
#  ('도움', 'NNG'),
#  ('을', 'JKO'),
#  ('주', 'VV'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('목적', 'NNG'),
#  ('으로', 'JKB'),
#  ('제정', 'NNG'),
#  ('되', 'XSV'),
#  ('었', 'EP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('의', 'JKG'),
#  ('내용', 'NNG'),
#  ('및', 'MAJ'),
#  ('구성', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('은', 'JX'),
#  ('국내외', 'NNG'),
#  ('환경', 'NNG'),
#  ('정책', 'NNG'),
#  ('과', 'JC'),
#  ('관행', 'NNG'),
#  ('에', 'JKB'),
#  ('부합', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('의', 'JKG'),
#  ('원칙', 'NNG'),
#  ('과', 'JC'),
#  ('기준', 'NNG'),
#  ('을', 'JKO'),
#  ('담', 'VV'),
#  ('고자', 'EC'),
#  ('한다', 'VX+EF'),
#  ('.', 'SF'),
#  ('또한', 'MAJ'),
#  ('현행', 'NNG'),
#  ('법령', 'NNG'),
#  ('상', 'XSN'),
#  ('의', 'JKG'),
#  ('요구', 'NNG'),
#  ('를', 'JKO'),
#  ('수용', 'NNG'),
#  ('하', 'XSV'),
#  ('면서', 'EC'),
#  ('도', 'JX'),
#  ('미래', 'NNG'),
#  ('지향', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('관점', 'NNG'),
#  ('에서', 'JKB'),
#  ('국내', 'NNG'),
#  ('기업', 'NNG'),
#  ('들', 'XSN'),
#  ('이', 'JKS'),
#  ('추구', 'NNG'),
#  ('하', 'XSV'),
#  ('여야', 'EC'),
#  ('할', 'VX+ETM'),
#  ('바람직', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('의', 'JKG'),
#  ('방향', 'NNG'),
#  ('도', 'JX'),
#  ('함께', 'MAG'),
#  ('제시', 'NNG'),
#  ('하', 'XSV'),
#  ('고자', 'EC'),
#  ('한다', 'VX+EF'),
#  ('.', 'SF'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('위해', 'VV+EC'),
#  ('본', 'VX+ETM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('은', 'JX'),
#  ('전문', 'NNG'),
#  (',', 'SC'),
#  ('리더십', 'NNG'),
#  ('과', 'JC'),
#  ('거버넌스', 'NNP'),
#  (',', 'SC'),
#  ('위험', 'NNG'),
#  ('관리', 'NNG'),
#  (',', 'SC'),
#  ('운영', 'NNG'),
#  ('및', 'MAJ'),
#  ('성과', 'NNG'),
#  (',', 'SC'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('소통', 'NNG'),
#  (',', 'SC'),
#  ('부록', 'NNG'),
#  ('등', 'NNB'),
#  ('네', 'MM'),
#  ('부문', 'NNG'),
#  ('의', 'JKG'),
#  ('본문', 'NNG'),
#  ('과', 'JC'),
#  ('부록', 'NNG'),
#  ('으로', 'JKB'),
#  ('구성', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('의', 'JKG'),
#  ('적용', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('은', 'JX'),
#  ('상장', 'NNG'),
#  ('기업', 'NNG'),
#  ('을', 'JKO'),
#  ('비롯', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('공개', 'NNG'),
#  ('기업', 'NNG'),
#  ('을', 'JKO'),
#  ('적용', 'NNG'),
#  ('대상', 'NNG'),
#  ('으로', 'JKB'),
#  ('하', 'VV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('그러나', 'MAJ'),
#  ('비', 'XPN'),
#  ('공개', 'NNG'),
#  ('기업', 'NNG'),
#  ('도', 'JX'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('을', 'JKO'),
#  ('준수', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('이', 'JKS'),
#  ('바람직', 'XR'),
#  ('하', 'XSA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('기업', 'NNG'),
#  ('활동', 'NNG'),
#  ('이', 'JKS'),
#  ('환경', 'NNG'),
#  ('에', 'JKB'),
#  ('미치', 'VV'),
#  ('는', 'ETM'),
#  ('영향', 'NNG'),
#  ('은', 'JX'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('산업', 'NNG'),
#  ('적', 'XSN'),
#  ('특성', 'NNG'),
#  ('및', 'MAJ'),
#  ('상황', 'NNG'),
#  ('에', 'JKB'),
#  ('따라', 'VV+EC'),
#  ('상이', 'XR'),
#  ('하', 'XSA'),
#  ('며', 'EC'),
#  ('끊임없이', 'MAG'),
#  ('변화', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('으므로', 'EC'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('또한', 'MAJ'),
#  ('유연', 'XR'),
#  ('하', 'XSA'),
#  ('고', 'EC'),
#  ('탄력', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('운영', 'NNG'),
#  ('되', 'XSV'),
#  ('어야', 'EC'),
#  ('한다', 'VX+EC'),
#  ('.', 'SY'),
#  ('6', 'SN'),
#  ('❘', 'SY'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('본', 'MM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('은', 'JX'),
#  ('다양', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('글로벌', 'NNG'),
#  ('가이드라인', 'NNG'),
#  ('에', 'JKB'),
#  ('기반', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('는', 'ETM'),
#  ('바', 'NNB'),
#  ('국내', 'NNG'),
#  ('기업', 'NNG'),
#  ('은', 'JX'),
#  ('본', 'VV+ETM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('을', 'JKO'),
#  ('기본', 'NNG'),
#  ('으로', 'JKB'),
#  ('자발', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('체계', 'NNG'),
#  ('를', 'JKO'),
#  ('구축', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'EC'),
#  ('운영', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  (',', 'SC'),
#  ('지속', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('검토', 'NNG'),
#  ('를', 'JKO'),
#  ('통하', 'VV'),
#  ('여', 'EC'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('발전', 'NNG'),
#  ('시켜', 'XSV+EC'),
#  ('나가', 'VX'),
#  ('야', 'EC'),
#  ('할', 'VX+ETM'),
#  ('것', 'NNB'),
#  ('이', 'VCP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('또한', 'MAJ'),
#  ('본', 'MM'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('도', 'JX'),
#  ('국내외', 'NNG'),
#  ('적', 'XSN'),
#  ('상황', 'NNG'),
#  ('변화', 'NNG'),
#  ('를', 'JKO'),
#  ('고려', 'NNG'),
#  ('하', 'XSV'),
#  ('여', 'EC'),
#  ('계속', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('재', 'XPN'),
#  ('검토', 'NNG'),
#  ('되', 'XSV'),
#  ('어야', 'EC'),
#  ('할', 'VX+ETM'),
#  ('것', 'NNB'),
#  ('이', 'VCP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('의', 'JKG'),
#  ('개정', 'NNG'),
#  ('배경', 'NNG'),
#  ('지난', 'VV+ETM'),
#  ('2010', 'SN'),
#  ('년', 'NNBC'),
#  ('에', 'JKB'),
#  ('제정', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC'),
#  ('발표', 'NNG'),
#  ('된', 'XSV+ETM'),
#  ('환경', 'NNG'),
#  ('모범', 'NNG'),
#  ('규준', 'NNG'),
#  ('은', 'JX'),
#  ('그동안', 'NNG'),
#  ('국내', 'NNG'),
#  ('상장', 'NNG'),
#  ('기업', 'NNG'),
#  ('의', 'JKG'),
#  ('환경', 'NNG'),
#  ('경영', 'NNG'),
#  ('개선', 'NNG'),
#  ('을', 'JKO'),
#  ('선도', 'NNG'),
#  ('해', 'XSV+EC'),
#  ('왔', 'VX+EP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('하', 'VV'),
#  ('지만', 'EC'),
#  ('지난', 'VV+ETM'),
#  ('10', 'SN'),
#  ('년', 'NNBC'),
#  ('간', 'NNG'),
#  ('국제', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('환경', 'NNG'),
#  ('에', 'JKB'),
#  ('대한', 'VV+ETM'),
#  ('경각심', 'NNG'),
#  ('이', 'JKS'),
#  ('커짐', 'VA+EC+VX+ETN'),
#  ('에', 'JKB'),
#  ('따라', 'VV+EC'),
#  ('관련', 'NNG'),
#  ('글로벌', 'NNG'),
#  ('규준', 'NNG'),
#  ('이', 'JKS'),
#  ('지속', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('발전', 'NNG'),
#  ('되', 'XSV'),
#  ('어', 'EC'),
#  ('왔으며', 'VX+EP+EC'),
#  (',', 'SC'),
#  ('국내', 'NNG'),
#  ...]

# %%
from konlpy.tag import Mecab
mecab = Mecab()
stop = ["위해", "등", "및", "경우", "한다", "위한", "부록", "관련", "위험", "이해", "평가", "감사", "필요", "책임", "사항", "기능"]

nodes = [t[0] for t in tokens]
vocab = [t[0] for t in tokens if t[0] not in stop if t[1] in ['NNG', 'NNP'] and len(t[0]) > 1]

print(nodes[:10])
print(vocab[:10])
# Out:
# ['(', 'cid', ':', '47', ')', '(', 'cid', ':', '51', ')']
# ['환경', '모범', '규준', '전문', '리더십', '거버넌스', '관리', '운영', '성과', '관계자']

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

count = Counter(vocab)
words = dict(count.most_common())

# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "summer", 
                      width=2000, height=1500).generate_from_frequencies(words) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %%
vocab = list(set(vocab))

vocab2idx = {vocab[i]:i for i in range(len(vocab))}
idx2vocab = {i:vocab[i] for i in range(len(vocab))}

# %%
import numpy as np
import math

vocab_len = len(vocab2idx)

# 토큰별로 그래프 edge를 Matrix 형태로 생성
weighted_edge = np.zeros((vocab_len,vocab_len),dtype=np.float32)

# 각 토큰 노드별로 스코어 1로 초기화
score = np.ones((vocab_len),dtype=np.float32)

# coocurrence를 판단하기 위한 window 사이즈 설정
window_size = 4
covered_coocurrences = []

for window_start in range(len(nodes) - window_size + 1):
    window = nodes[window_start:window_start+window_size]
    for i in range(window_size):
        for j in range(i+1, window_size):
            if window[i] in vocab and window[j] in vocab:
                index_i = window_start + i
                index_j = window_start + j

                if (index_i, index_j) not in covered_coocurrences:
                    weighted_edge[vocab2idx[window[i]]][vocab2idx[window[j]]] = 1
                    weighted_edge[vocab2idx[window[j]]][vocab2idx[window[i]]] = 1
                    covered_coocurrences.append((index_i, index_j))

for i in range(vocab_len):
    row_sum = weighted_edge[i].sum()
    weighted_edge[i] = weighted_edge[i]/row_sum if row_sum > 0 else 0

MAX_ITERATIONS = 50
d=0.85
threshold = 0.0001 #convergence threshold

for iter in range(MAX_ITERATIONS):
    prev_score = np.copy(score)

    for i in range(vocab_len):
        summation = 0
        for j in range(vocab_len):
            if weighted_edge[j][i] != 0:
                summation += weighted_edge[j][i] * prev_score[j]

        score[i] = (1 - d) * d*summation

    if np.sum(np.fabs(prev_score -  score)) <= threshold:
        break


sorted_index = np.flip(np.argsort(score), 0)

n = 50


print("\n=== 핵심키워드 ===")
for i in range(0,n):
    print(str(idx2vocab[sorted_index[i]])+" : " + str(score[sorted_index[i]]))
# Out:
# === 핵심키워드 ===
# 기업 : 4.3043865e-08
# 환경 : 2.3862471e-08
# 정보 : 1.99223e-08
# 경영 : 1.9778154e-08
# 사회 : 1.8936435e-08
# 관리 : 1.3488449e-08
# 주주 : 1.312938e-08
# 활동 : 1.3089775e-08
# 이사 : 1.2796216e-08
# 위원회 : 1.0762881e-08
# 소비자 : 1.0425972e-08
# 가능 : 1.0416975e-08
# 제품 : 9.9188435e-09
# 관계자 : 9.041184e-09
# 주요 : 8.9964365e-09
# 발생 : 8.996229e-09
# 활용 : 8.916145e-09
# 내부 : 8.866797e-09
# 이사회 : 8.482991e-09
# 사업 : 8.416819e-09
# 거래 : 8.402519e-09
# 고려 : 8.351639e-09
# 지속 : 8.351204e-09
# 다양 : 8.295024e-09
# 결정 : 8.247378e-09
# 과정 : 8.193848e-09
# 보호 : 8.192009e-09
# 인권 : 8.098115e-09
# 친환경 : 7.89575e-09
# 체계 : 7.792992e-09
# 운영 : 7.712879e-09
# 제도 : 7.641582e-09
# 개선 : 7.641278e-09
# 전략 : 7.551052e-09
# 재무 : 7.4643784e-09
# 제공 : 7.454912e-09
# 변화 : 7.4479654e-09
# 에너지 : 7.4275555e-09
# 공정 : 7.4193283e-09
# 성과 : 7.388585e-09
# 근로자 : 7.3640996e-09
# 지원 : 7.356539e-09
# 정책 : 7.246761e-09
# 중요 : 7.1755535e-09
# 내용 : 7.1597013e-09
# 사용 : 7.130183e-09
# 생산 : 6.9899477e-09
# 물질 : 6.868568e-09
# 공시 : 6.8478254e-09
# 수립 : 6.843655e-09

# %%
w = []
v = []
for i in range(0, 1954) :
    w.append(str(idx2vocab[sorted_index[i]]))
    v.append(str(score[sorted_index[i]]))

# %%
import pandas as pd
environment_df = pd.DataFrame({"keyword" : w,  "score" : v})
environment_df.astype({"score" : float})
environment_df.to_csv("ESG_standard.csv")

# %%
import numpy as np
import math
import networkx as nx

# 윈도내 동시 등장한 토큰으로 그래프를 생성
def connect(vocab, nodes) :            
    window_size = 3

    edges = []
    for window_start in range(len(nodes) - window_size + 1):
        window = nodes[window_start: window_start + window_size]
        for i in range(window_size):
            for j in range(i + 1, window_size):
                if window[i] in vocab and window[j] in vocab:
                    edges.append((window[i], window[j]))
      
    return edges


graph=nx.diamond_graph()
graph.clear() 
graph.add_nodes_from(vocab) #node 등록
graph.add_edges_from(connect(vocab, nodes)) #edge 연결    

scores = nx.pagerank(graph) #pagerank 계산

rank = sorted(scores.items(), key=lambda x: x[1], reverse=True) #score 역순 정렬
print("\n=== 핵심키워드 ===")
rank[:10]
# Out:
# === 핵심키워드 ===
# [('기업', 0.02055063207364064),
#  ('환경', 0.00915224967673441),
#  ('정보', 0.00805099606371168),
#  ('경영', 0.006825177114290477),
#  ('사회', 0.006676179675899768),
#  ('주주', 0.005696559293508332),
#  ('활동', 0.005286886267340571),
#  ('이사', 0.0052406891448339476),
#  ('위원회', 0.004756046486577957),
#  ('관리', 0.004217800625717688)]

# %%
keyword = []
for i in range(0,15):
    keyword.append(str(idx2vocab[sorted_index[i]]))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

n_topic = 3

tfidf_vect = TfidfVectorizer()
tfidf = tfidf_vect.fit_transform(keyword)
svd = TruncatedSVD(n_components=n_topic, n_iter=100)

U = svd.fit_transform(tfidf)
Vt = svd.components_

# %%
vocab = tfidf_vect.get_feature_names()
print(vocab)
n = 3
for i, topic in enumerate(Vt):
    print("Topic {}".format(i), [ (vocab[i], topic[i], round(3)) for i in topic.argsort()[:-n-1:-1]])
# Out:
# ['감사', '경영', '관련', '관리', '기업', '사회', '위험', '이사', '이해', '정보', '주주', '평가', '필요', '환경', '활동']
# Topic 0 [('주주', 0.4514189454253261, 3), ('감사', 0.401354259948692, 3), ('이사', 0.36568391777586895, 3)]
# Topic 1 [('환경', 0.40985651431146514, 3), ('이사', 0.40782146383809115, 3), ('위험', 0.3534345182855224, 3)]
# Topic 2 [('감사', 0.37300595108076207, 3), ('환경', 0.33716487055836075, 3), ('관련', 0.2968161689389636, 3)]

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

def calc_simiarlty_matrix(vectors):
    def consine_similarity(a,b):
        return dot(a,b)/(norm(a)*norm(b))
    
    n_word = len(vectors)
    similarity_matrix = np.zeros((n_word, n_word))
    
    for i in range(n_word):
        for j in range(n_word):
            similarity_matrix[j, i] = consine_similarity(vectors[i], vectors[j]).round(4)

    return similarity_matrix

# %%
word_vectors = Vt.T
word_similarity_matrix = calc_simiarlty_matrix(word_vectors)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_similarity(similarity_matrix, label):
    mask = np.triu(np.ones_like(similarity_matrix, dtype=np.bool))
    plt.rcParams['figure.figsize'] = [10, 8]
    plt.rc('font', family='Malgun Gothic')
    ax = sns.heatmap(similarity_matrix, mask=mask, xticklabels=label, yticklabels=label,
                     annot=True, fmt=".2f", annot_kws={"size":8},cmap="coolwarm")

# %%
visualize_similarity(word_similarity_matrix, vocab)

# %%
from sklearn.manifold import TSNE

def visualize_vectors(vectors, labels):
    tsne = TSNE(n_components=2, n_iter=10000, perplexity=2)
    np.set_printoptions(suppress=True)
    T = tsne.fit_transform(vectors)

    plt.figure(figsize=(10, 6))
    plt.scatter(T[:,0], T[:, 1], c='orange', edgecolors='r')
    for label, x, y in zip(labels, T[:,0], T[:, 1]):
        plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
visualize_vectors(word_vectors, vocab)

# %%
ESG_standard = ESG_standard.replace("\n", " ")
test = re.sub("[0-9\•\/\(\)\[\]\{\}\·\'\'\"\"\`\%\㎡\*\━\‘\’\●\★\,]+", " ", ESG_standard).replace("\x0c", "")

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\rnru1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sent_text = sent_tokenize(test)

# %%
normalized_text = []
for string in sent_text:
    tokens = re.sub(r"[^a-z0-9가-힣]+", " ", string.lower())
    normalized_text.append(tokens)

result = [word_tokenize(sentence) for sentence in normalized_text]

# %%
print('총 샘플의 개수 : {}'.format(len(result)))
# Out:
# 총 샘플의 개수 : 1548

# %%
for line in result[:3]:
    print(line)
# Out:
# ['cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'cid', 'contents', 'contents', '환경', '모범규준', '전문', '리더십과', '거버넌스', '위험', '관리', '운영', '및', '성과', '이해관계자', '소통', '부록', '참고문헌', '사회', '모범규준', '전문', '리더십과', '거버넌스', '비재무', '위험', '관리', '운영', '및', '성과', '이해관계자', '소통', '부록', '참고문헌', '지배구조', '모범규준', '전문', '이사회', '리더십', '주주권', '보호', '감사', '주주', '및', '이해관계자와의', '소통', '참고문헌', '환경', '모범규준', '전문', '리더십과', '거버넌스', '위험', '관리', '운영', '및', '성과', '이해관계자', '소통', '부록', '참고문헌', 'korea', 'corporate', 'governance', 'service', '전문', '환경', '모범규준의', '제정', '배경', '기업경영에', '있어', '환경문제가', '기업의', '지속가능한', '발전에', '중요한', '영향을', '미치는', '변수로', '부각됨에', '따라', '국내', '기업도', '환경경영을', '통해', '기업의', '지속가능성과', '수익성을', '동시에', '고려하려는', '세계적', '흐름에', '적극적이고', '능동적으로', '대처할', '필요가', '있다']
# ['특히', '환경의', '질을', '개선하려는', '활동에', '대한', '관심이', '지속적으로', '증대됨에', '따라', '기업의', '경영활동이', '환경에', '미치는', '영향은', '기업의', '생존가능성과', '경쟁력에', '중요한', '요소가', '되고', '있다']
# ['이러한', '시대적', '요청에', '부응하여', '국내기업들은', '환경경영을', '수행하기', '위해', '지속적으로', '노력하여야', '하며', '주주를', '포함한', '다양한', '이해관계자들의', '신뢰를', '얻기', '위하여', '체계적으로', '환경경영을', '수행할', '수', '있도록', '경영체제를', '구축할', '필요가', '있다']

# %%
from gensim.models import Word2Vec
model = Word2Vec(sentences=result, size=100, window=5, min_count=5, workers=4, sg=0)
# Out:
# C:\Users\rnru1\anaconda3\envs\abangues\lib\site-packages\gensim\utils.py:1212: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# WARNING:gensim.models.base_any2vec:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model_result = model.wv.most_similar("지배구조")
print(model_result)
# Out:
# [('사회', 0.9997446537017822), ('부록', 0.9997266530990601), ('환경', 0.9997085332870483), ('한다', 0.9996963739395142), ('경우', 0.9996916651725769), ('위한', 0.9996903538703918), ('아니라', 0.9996864795684814), ('모든', 0.9996805191040039), ('관련', 0.9996790885925293), ('정보', 0.9996789693832397)]

# %%
mr_w = []
mr_s = []
for i in model_result :
    mr_w.append(i[0])
    mr_s.append(i[1])
plt.bar
# Out:
# 0.9997446537017822
# 0.9997266530990601
# 0.9997085332870483
# 0.9996963739395142
# 0.9996916651725769
# 0.9996903538703918
# 0.9996864795684814
# 0.9996805191040039
# 0.9996790885925293
# 0.9996789693832397
