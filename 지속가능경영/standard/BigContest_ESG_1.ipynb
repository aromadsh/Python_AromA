# %%
pip install pdfminer3k
# Out:
# Requirement already satisfied: pdfminer3k in c:\users\rnru1\anaconda3\envs\abangues\lib\site-packages (1.3.4)
# Requirement already satisfied: ply in c:\users\rnru1\anaconda3\envs\abangues\lib\site-packages (from pdfminer3k) (3.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdfminer.pdfinterp import PDFResourceManager, process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from io import open
from urllib.request import urlopen
import re
import os

# %%
def read_pdf_file(pdfFile):
    pdfrm = PDFResourceManager()
    strio = StringIO()
    lapa = LAParams()
    device = TextConverter(pdfrm, strio, laparams = lapa)
    
    process_pdf(pdfrm, device, pdfFile)
    device.close()
    
    content = strio.getvalue()
    strio.close()
    return content

# %%
pdf_samsung = open("삼성디스플레이.pdf", "rb")
samsung_display = read_pdf_file(pdf_samsung)
pdf_samsung.close() 

pdf_skens = open("SK E&S.pdf", "rb")
sk_ens = read_pdf_file(pdf_skens)
pdf_skens.close()

pdf_skens = open("SK머티리얼즈.pdf", "rb")
sk_muti = read_pdf_file(pdf_skens)
pdf_skens.close()

pdf_skens = open("아시아문화원.pdf", "rb")
sk_asia = read_pdf_file(pdf_skens)
pdf_skens.close()

pdf_skens = open("현대로템.pdf", "rb")
sk_hyun = read_pdf_file(pdf_skens)
pdf_skens.close()
# Out:
# WARNING:pdfminer.layout:Too many boxes (106) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (114) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (134) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (145) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (102) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (215) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (280) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (173) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (131) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (220) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (124) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (107) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (123) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (111) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (118) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (135) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (179) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (203) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (110) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (166) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (141) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (106) to group, skipping.
# WARNING:root:Wrong type: <PDFStream(3): raw=274, {'Filter': /FlateDecode, 'Length': 274}> required: <class 'dict'>
# WARNING:root:Cannot locate objid=4
# WARNING:pdfminer.layout:Too many boxes (104) to group, skipping.
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='CCMXSB+YoonGothicPro770', cidcoding='Adobe-Korea1'>, 1592
# WARNING:pdfminer.layout:Too many boxes (119) to group, skipping.
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 3351
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 3351
# WARNING:pdfminer.layout:Too many boxes (107) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (156) to group, skipping.
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 3351
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 3351
# WARNING:pdfminer.layout:Too many boxes (132) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (101) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (131) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (110) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (108) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (101) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (109) to group, skipping.
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 1604
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 1604
# WARNING:pdfminer.converter:undefined: <PDFCIDFont: basefont='QUVMXN+YoonGothicPro730', cidcoding='Adobe-Korea1'>, 1591
# WARNING:pdfminer.layout:Too many boxes (301) to group, skipping.
# WARNING:root:Cannot locate objid=15265
# WARNING:pdfminer.layout:Too many boxes (114) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (102) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (127) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (148) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (103) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (117) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (117) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (108) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (159) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (118) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (127) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (135) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (120) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (103) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (131) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (126) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (226) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (155) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (127) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (210) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (151) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (150) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (140) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (155) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (113) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (126) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (105) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (108) to group, skipping.

# %%
from konlpy.tag import Mecab
mecab = Mecab()

tokens = []
def word_token (x) :
    for token in mecab.pos(x):
        tokens.append(token)
    return tokens

word_token(samsung_display)
word_token(sk_ens)
word_token(sk_muti)
word_token(sk_asia)
word_token(sk_hyun)
# Out:
# [('SAMSUNG', 'SL'),
#  ('DISPLAY', 'SL'),
#  ('Sustainability', 'SL'),
#  ('Report', 'SL'),
#  ('2021', 'SN'),
#  ('SEE', 'SL'),
#  ('THROUGH', 'SL'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('우리', 'NP'),
#  ('는', 'JX'),
#  ('SEE', 'SL'),
#  ('THROUGH', 'SL'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('내일', 'NNG'),
#  ('을', 'JKO'),
#  ('봅니다', 'VV+EC'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('세상', 'NNG'),
#  ('을', 'JKO'),
#  ('바라본다는', 'VV+ETM'),
#  ('것', 'NNB'),
#  ('단순히', 'MAG'),
#  ('보', 'VV'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('만', 'JX'),
#  ('이', 'JKC'),
#  ('아닙니다', 'VCN+EF'),
#  ('그', 'MM'),
#  ('속', 'NNG'),
#  ('에서', 'JKB'),
#  ('우리', 'NP'),
#  ('를', 'JKO'),
#  ('발견', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('더', 'MAG'),
#  ('나아가', 'VV'),
#  ('서', 'EC'),
#  ('함께', 'MAG'),
#  ('살아가', 'VV'),
#  ('야', 'EC'),
#  ('할', 'VX+ETM'),
#  ('지구촌', 'NNG'),
#  ('가족', 'NNG'),
#  ('을', 'JKO'),
#  ('봅니다', 'VV+EC'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('세상', 'NNG'),
#  ('을', 'JKO'),
#  ('보여', 'VV+EC'),
#  ('준다는', 'VX+ETM'),
#  ('것', 'NNB'),
#  ('단순히', 'MAG'),
#  ('보여', 'VV+EC'),
#  ('주', 'VX'),
#  ('는', 'ETM'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('넘어서', 'VV'),
#  ('서', 'EC'),
#  ('무한', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('가능', 'NNG'),
#  ('성', 'XSN'),
#  ('과', 'JC'),
#  ('대', 'XPN'),
#  ('자연', 'NNG'),
#  ('의', 'JKG'),
#  ('섭리', 'NNG'),
#  ('그리고', 'MAJ'),
#  ('거기', 'NP'),
#  ('서', 'JKB'),
#  ('소통', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('나누', 'VV'),
#  ('는', 'ETM'),
#  ('마음', 'NNG'),
#  ('을', 'JKO'),
#  ('보여', 'VV+EC'),
#  ('줍니다', 'VV+EC'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('우리', 'NP'),
#  ('는', 'JX'),
#  ('네모난', 'VA+ETM'),
#  ('세상', 'NNG'),
#  ('둥그런', 'VA+EC'),
#  ('세상', 'NNG'),
#  ('을', 'JKO'),
#  ('떠나', 'VV+EC'),
#  ('규정', 'NNG'),
#  ('할', 'XSV+ETM'),
#  ('수', 'NNB'),
#  ('없', 'VA'),
#  ('는', 'ETM'),
#  ('무한', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('가능', 'NNG'),
#  ('성', 'XSN'),
#  ('의', 'JKG'),
#  ('세계', 'NNG'),
#  ('그', 'MM'),
#  ('안', 'NNG'),
#  ('에서', 'JKB'),
#  ('유연', 'XR'),
#  ('하', 'XSA'),
#  ('고', 'EC'),
#  ('혁신', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('내일', 'NNG'),
#  ('을', 'JKO'),
#  ('만납니다', 'VV+EF'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('ABOUT', 'SL'),
#  ('THIS', 'SL'),
#  ('REPORT', 'SL'),
#  ('보고서', 'NNG'),
#  ('개요', 'NNG'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('는', 'JX'),
#  ('경영', 'NNG'),
#  ('활동', 'NNG'),
#  ('을', 'JKO'),
#  ('통해', 'VV+EC'),
#  ('창출', 'NNG'),
#  ('되', 'XSV'),
#  ('는', 'ETM'),
#  ('경제', 'NNG'),
#  (',', 'SC'),
#  ('사회', 'NNG'),
#  (',', 'SC'),
#  ('환경', 'NNG'),
#  ('적', 'XSN'),
#  ('가치', 'NNG'),
#  ('와', 'VV+EC'),
#  ('성과', 'NNG'),
#  ('를', 'JKO'),
#  ('다양', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('에게', 'JKB'),
#  ('투명', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'EC'),
#  ('공개', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('소통', 'NNG'),
#  ('하', 'XSV'),
#  ('고자', 'EC'),
#  ('첫', 'MM'),
#  ('번', 'NNBC'),
#  ('째', 'XSN'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('경영', 'NNG'),
#  ('보고서', 'NNG'),
#  ('를', 'JKO'),
#  ('발간', 'NNG'),
#  ('합니다', 'XSV+EF'),
#  ('.', 'SF'),
#  ('보', 'VV'),
#  ('고', 'EC'),
#  ('기간', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('보고서', 'NNG'),
#  ('는', 'JX'),
#  ('2020', 'SN'),
#  ('년', 'NNBC'),
#  ('1', 'SN'),
#  ('월', 'NNBC'),
#  ('1', 'SN'),
#  ('일', 'NNBC'),
#  ('부터', 'JX'),
#  ('2020', 'SN'),
#  ('년', 'NNBC'),
#  ('12', 'SN'),
#  ('월', 'NNBC'),
#  ('31', 'SN'),
#  ('일', 'NNBC'),
#  ('까지', 'JX'),
#  ('의', 'JKG'),
#  ('경제', 'NNG'),
#  (',', 'SC'),
#  ('사', 'NR'),
#  ('회', 'NNBC'),
#  (',', 'SC'),
#  ('환경', 'NNG'),
#  ('적', 'XSN'),
#  ('성과', 'NNG'),
#  ('와', 'JC'),
#  ('활동', 'NNG'),
#  ('을', 'JKO'),
#  ('담', 'VV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('으며', 'EC'),
#  (',', 'SC'),
#  ('일부', 'NNG'),
#  ('성과', 'NNG'),
#  ('의', 'JKG'),
#  ('경우', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('2021', 'SN'),
#  ('년', 'NNBC'),
#  ('5', 'SN'),
#  ('월', 'NNBC'),
#  ('까지', 'JX'),
#  ('의', 'JKG'),
#  ('정보', 'NNG'),
#  ('를', 'JKO'),
#  ('포함', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('연속', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('추이', 'NNG'),
#  ('파악', 'NNG'),
#  ('이', 'JKS'),
#  ('필요', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('성과', 'NNG'),
#  ('의', 'JKG'),
#  ('경우', 'NNG'),
#  ('이전', 'NNG'),
#  ('3', 'SN'),
#  ('개년', 'NNBC'),
#  ('이상', 'NNG'),
#  ('의', 'JKG'),
#  ('데이터', 'NNG'),
#  ('를', 'JKO'),
#  ('제시', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('보', 'VV'),
#  ('고', 'EC'),
#  ('범위', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('보고서', 'NNG'),
#  ('는', 'JX'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('의', 'JKG'),
#  ('국내외', 'NNG'),
#  ('전', 'MM'),
#  ('사업장', 'NNG'),
#  ('과', 'JC'),
#  ('공급', 'NNG'),
#  ('망', 'NNG'),
#  ('을', 'JKO'),
#  ('포함', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('보', 'VV'),
#  ('고', 'EC'),
#  ('범위', 'NNG'),
#  ('가', 'JKS'),
#  ('상이', 'XR'),
#  ('한', 'XSA+ETM'),
#  ('경우', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('독자', 'NNG'),
#  ('의', 'JKG'),
#  ('참고', 'NNG'),
#  ('사항', 'NNG'),
#  ('으로', 'JKB'),
#  ('별도', 'NNG'),
#  ('표', 'NNG'),
#  ('기하', 'NNG'),
#  ('였', 'VCP+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('작성', 'NNG'),
#  ('기준', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('보고서', 'NNG'),
#  ('는', 'JX'),
#  ('GRI', 'SL'),
#  ('(', 'SSO'),
#  ('Global', 'SL'),
#  ('Reporting', 'SL'),
#  ('Initiative', 'SL'),
#  (')', 'SSC'),
#  ('Standards', 'SL'),
#  ('의', 'JKG'),
#  ('‘', 'SY'),
#  ('Core', 'SL'),
#  ('Option', 'SL'),
#  ('’', 'SY'),
#  ('을', 'JKO'),
#  ('따르', 'VV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('으며', 'EC'),
#  (',', 'SC'),
#  ('UN', 'SL'),
#  ('SDGs', 'SL'),
#  ('(', 'SSO'),
#  ('Sustainable', 'SL'),
#  ('Development', 'SL'),
#  ('Goals', 'SL'),
#  (')', 'SSC'),
#  ('와', 'JC'),
#  ('TCFD', 'SL'),
#  ('(', 'SSO'),
#  ('Task', 'SL'),
#  ('Force', 'SL'),
#  ('on', 'SL'),
#  ('Climate', 'SL'),
#  ('-', 'SY'),
#  ('related', 'SL'),
#  ('Financial', 'SL'),
#  ('Disclosures', 'SL'),
#  (')', 'SSC'),
#  ('의', 'JKG'),
#  ('지표', 'NNG'),
#  ('를', 'JKO'),
#  ('반영', 'NNG'),
#  ('했', 'XSV+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('보', 'VV'),
#  ('고서', 'EC'),
#  ('내', 'NP+JKG'),
#  ('재무', 'NNG'),
#  ('성과', 'NNG'),
#  ('는', 'JX'),
#  ('K', 'SL'),
#  ('-', 'SY'),
#  ('IFRS', 'SL'),
#  ('(', 'SSO'),
#  ('한국', 'NNP'),
#  ('채택', 'NNG'),
#  ('국제회계기준', 'NNP'),
#  (')', 'SSC'),
#  ('연결', 'NNG'),
#  ('기준', 'NNG'),
#  ('으로', 'JKB'),
#  ('작성', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('보', 'VV'),
#  ('고서', 'EC'),
#  ('검증', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('보고서', 'NNG'),
#  ('는', 'JX'),
#  ('보', 'VV'),
#  ('고', 'EC'),
#  ('내용', 'NNG'),
#  ('의', 'JKG'),
#  ('신뢰', 'NNG'),
#  ('성', 'XSN'),
#  ('확보', 'NNG'),
#  ('를', 'JKO'),
#  ('위하', 'VV'),
#  ('여', 'EC'),
#  ('독립', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('외부', 'NNG'),
#  ('검증', 'NNG'),
#  ('기관', 'NNG'),
#  ('인', 'VCP+ETM'),
#  ('BSI', 'SL'),
#  ('의', 'JKG'),
#  ('검증', 'NNG'),
#  ('과정', 'NNG'),
#  ('을', 'JKO'),
#  ('거쳤으며', 'VV+EP+EC'),
#  (',', 'SC'),
#  ('보고서', 'NNG'),
#  ('검증', 'NNG'),
#  ('은', 'JX'),
#  ('국제', 'NNG'),
#  ('적', 'XSN'),
#  ('검증', 'NNG'),
#  ('기', 'NNG'),
#  ('준', 'NNG'),
#  ('인', 'VCP+ETM'),
#  ('AA', 'SL'),
#  ('1000', 'SN'),
#  ('AS', 'SL'),
#  ('에', 'JKB'),
#  ('따라', 'VV+EC'),
#  ('수행', 'NNG'),
#  ('되', 'XSV'),
#  ('었', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('세부', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('검증', 'NNG'),
#  ('의견서', 'NNG'),
#  ('는', 'JX'),
#  ('Appendix', 'SL'),
#  ('에', 'JKB'),
#  ('수록', 'NNG'),
#  ('하', 'XSV'),
#  ('였', 'EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('추가', 'NNG'),
#  ('정보', 'NNG'),
#  ('본', 'VV+ETM'),
#  ('보고서', 'NNG'),
#  ('는', 'JX'),
#  ('국문', 'NNG'),
#  ('과', 'JC'),
#  ('영문', 'NNG'),
#  ('으로', 'JKB'),
#  ('발간', 'NNG'),
#  ('되', 'XSV'),
#  ('며', 'EC'),
#  (',', 'SC'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('홈페이지', 'NNG'),
#  ('및', 'MAJ'),
#  ('뉴스룸', 'NNP'),
#  ('을', 'JKO'),
#  ('통해', 'VV+EC'),
#  ('열람', 'NNG'),
#  ('하', 'XSV'),
#  ('거나', 'EC'),
#  ('다운로드', 'NNG'),
#  ('받', 'VV'),
#  ('으실', 'EP+ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('본', 'VV+ETM'),
#  ('보고서', 'NNG'),
#  ('에', 'JKB'),
#  ('대한', 'VV+ETM'),
#  ('문', 'NNG'),
#  ('의', 'JKG'),
#  ('사항', 'NNG'),
#  ('은', 'JX'),
#  ('아래', 'NNG'),
#  ('연락처', 'NNG'),
#  ('로', 'JKB'),
#  ('문의', 'NNG'),
#  ('해', 'XSV+EC'),
#  ('주', 'VX'),
#  ('시', 'EP'),
#  ('기', 'ETN'),
#  ('바랍니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('━', 'SY'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('대표', 'NNG'),
#  ('홈페이지', 'NNG'),
#  ('www', 'SL'),
#  ('.', 'SY'),
#  ('samsungdisplay', 'SL'),
#  ('.', 'SY'),
#  ('com', 'SL'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('뉴스룸', 'NNP'),
#  ('news', 'SL'),
#  ('.', 'SY'),
#  ('samsungdisplay', 'SL'),
#  ('.', 'SY'),
#  ('com', 'SL'),
#  ('발간', 'NNG'),
#  ('담당', 'NNG'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('경영', 'NNG'),
#  ('사무국', 'NNG'),
#  ('이메일', 'NNG'),
#  ('csr', 'SL'),
#  ('.', 'SY'),
#  ('sdc', 'SL'),
#  ('@', 'SY'),
#  ('samsung', 'SL'),
#  ('.', 'SY'),
#  ('com', 'SL'),
#  ('Cover', 'SL'),
#  ('Story', 'SL'),
#  ('See', 'SL'),
#  ('through', 'SL'),
#  ('Samsung', 'SL'),
#  ('Display', 'SL'),
#  ('Meet', 'SL'),
#  ('sustainable', 'SL'),
#  ('life', 'SL'),
#  ('&', 'SY'),
#  ('world', 'SL'),
#  ('━', 'SY'),
#  ('10', 'SN'),
#  ('TABLE', 'SL'),
#  ('OF', 'SL'),
#  ('CONTENTS', 'SL'),
#  ('ESG', 'SL'),
#  ('HIGHLIGHT', 'SL'),
#  ('ENVIRONMENT', 'SL'),
#  ('녹색', 'NNG'),
#  ('경영', 'NNG'),
#  ('Planet', 'SL'),
#  ('First', 'SL'),
#  ('기후', 'NNG'),
#  ('변화', 'NNG'),
#  ('영향', 'NNG'),
#  ('관리', 'NNG'),
#  ('기후', 'NNG'),
#  ('변화', 'NNG'),
#  ('대응', 'NNG'),
#  ('전략', 'NNG'),
#  ('온실가스', 'NNG'),
#  ('배출', 'NNG'),
#  ('관리', 'NNG'),
#  ('에너지', 'NNG'),
#  ('효율', 'NNG'),
#  ('제고', 'NNG'),
#  ('대기', 'NNG'),
#  ('오염', 'NNG'),
#  ('물질', 'NNG'),
#  ('저감', 'NNG'),
#  ('순환', 'NNG'),
#  ('경제', 'NNG'),
#  ('실현', 'NNG'),
#  ('폐기물', 'NNG'),
#  ('및', 'MAJ'),
#  ('유해', 'NNG'),
#  ('화학', 'NNG'),
#  ('물질', 'NNG'),
#  ('관리', 'NNG'),
#  ('수자원', 'NNG'),
#  ('관리', 'NNG'),
#  ('생물', 'NNG'),
#  ('다양', 'NNG'),
#  ('성', 'XSN'),
#  ('보호', 'NNG'),
#  ('생물', 'NNG'),
#  ('다양', 'NNG'),
#  ('성', 'XSN'),
#  ('보호', 'NNG'),
#  ('활동', 'NNG'),
#  ('36', 'SN'),
#  ('37', 'SN'),
#  ('38', 'SN'),
#  ('43', 'SN'),
#  ('48', 'SN'),
#  ('SOCIAL', 'SL'),
#  ('고객', 'NNG'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('제품', 'NNG'),
#  ('제품', 'NNG'),
#  ('품질', 'NNG'),
#  ('및', 'MAJ'),
#  ('책임', 'NNG'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('마케팅', 'NNG'),
#  ('고객', 'NNG'),
#  ('만족', 'NNG'),
#  ('도', 'JX'),
#  ('관리', 'NNG'),
#  ('임직원', 'NNG'),
#  ('기본', 'NNG'),
#  ('권', 'XSN'),
#  ('존중', 'NNG'),
#  ('인재', 'NNG'),
#  ('유치', 'NNG'),
#  ('및', 'MAJ'),
#  ('역량', 'NNG'),
#  ('강화', 'NNG'),
#  ('근로', 'NNG'),
#  ('문화', 'NNG'),
#  ('및', 'MAJ'),
#  ('임직원', 'NNG'),
#  ('웰빙', 'NNP'),
#  ('안전', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('작업', 'NNG'),
#  ('환경', 'NNG'),
#  ('구축', 'NNG'),
#  ('[', 'SSO'),
#  ('Special', 'SL'),
#  ('Page', 'SL'),
#  (']', 'SSC'),
#  ('COVID', 'SL'),
#  ('-', 'SY'),
#  ('19', 'SN'),
#  ('대', 'NNBC'),
#  ('응', 'IC'),
#  ('활동', 'NNG'),
#  ('협력', 'NNG'),
#  ('회사', 'NNG'),
#  ('공정', 'NNG'),
#  ('거래', 'NNG'),
#  ('및', 'MAJ'),
#  ('상생', 'NNG'),
#  ('협력', 'NNG'),
#  ('공급', 'NNG'),
#  ('망', 'NNG'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('성', 'XSN'),
#  ('책임', 'NNG'),
#  ('있', 'VV'),
#  ('는', 'ETM'),
#  ('광물', 'NNG'),
#  ('소', 'NNG'),
#  ('싱', 'NNP'),
#  ('지역', 'NNG'),
#  ('사회', 'NNG'),
#  ('교육', 'NNG'),
#  ('사회', 'NNG'),
#  ('공헌', 'NNG'),
#  ('지역', 'NNG'),
#  ('사회', 'NNG'),
#  ('개발', 'NNG'),
#  ('기여', 'NNG'),
#  ('49', 'SN'),
#  ('50', 'SN'),
#  ('56', 'SN'),
#  ('71', 'SN'),
#  ('76', 'SN'),
#  ('MANAGEMENT', 'SL'),
#  ('OVERVIEW', 'SL'),
#  ('CEO', 'SL'),
#  ('Message', 'SL'),
#  ('Our', 'SL'),
#  ('Company', 'SL'),
#  ('OUR', 'SL'),
#  ('SUSTAINABILITY', 'SL'),
#  ('FRAMEWORK', 'SL'),
#  ('2025', 'SN'),
#  ('Sustainable', 'SL'),
#  ('Value', 'SL'),
#  ('Materiality', 'SL'),
#  ('Analysis', 'SL'),
#  ('Our', 'SL'),
#  ('Impact', 'SL'),
#  ('GOVERNANCE', 'SL'),
#  ('기업', 'NNG'),
#  ('지배', 'NNG'),
#  ('구조', 'NNG'),
#  ('건전', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('기업', 'NNG'),
#  ('지배', 'NNG'),
#  ('구조', 'NNG'),
#  ('리스크', 'NNG'),
#  ('관리', 'NNG'),
#  ('리스크', 'NNG'),
#  ('관리', 'NNG'),
#  ('정보', 'NNG'),
#  ('보안', 'NNG'),
#  ('과', 'JC'),
#  ('개인', 'NNG'),
#  ('정보', 'NNG'),
#  ('보호', 'NNG'),
#  ('기업', 'NNG'),
#  ('윤리', 'NNG'),
#  ('및', 'MAJ'),
#  ('컴플라이언스', 'NNG'),
#  ('준법', 'NNG'),
#  ('경영', 'NNG'),
#  ('투명', 'NNG'),
#  ('공시', 'NNG'),
#  ('12', 'SN'),
#  ('14', 'SN'),
#  ('24', 'SN'),
#  ('26', 'SN'),
#  ('32', 'SN'),
#  ('81', 'SN'),
#  ('82', 'SN'),
#  ('84', 'SN'),
#  ('87', 'SN'),
#  ('APPENDIX', 'SL'),
#  ('정량', 'NNG'),
#  ('성', 'XSN'),
#  ('과', 'JC'),
#  ('표', 'NNG'),
#  ('TCFD', 'SL'),
#  ('Index', 'SL'),
#  ('GRI', 'SL'),
#  ('Index', 'SL'),
#  ('UN', 'SL'),
#  ('SDGs', 'SL'),
#  ('수상', 'NNG'),
#  ('및', 'MAJ'),
#  ('가입', 'NNG'),
#  ('협회', 'NNG'),
#  ('제', 'XPN'),
#  ('3', 'SN'),
#  ('자', 'NNG'),
#  ('검증', 'NNG'),
#  ('의견서', 'NNG'),
#  ('91', 'SN'),
#  ('99', 'SN'),
#  ('100', 'SN'),
#  ('103', 'SN'),
#  ('104', 'SN'),
#  ('105', 'SN'),
#  ('Table', 'SL'),
#  ('of', 'SL'),
#  ('Contents', 'SL'),
#  ('11', 'SN'),
#  ('Samsung', 'SL'),
#  ('Display', 'SL'),
#  ('━', 'SY'),
#  ('Sustainability', 'SL'),
#  ('Report', 'SL'),
#  ('2021', 'SN'),
#  ('', 'SY'),
#  ('', 'SY'),
#  ('사람', 'NNG'),
#  ('과', 'JC'),
#  ('사람', 'NNG'),
#  (',', 'SC'),
#  ('사람', 'NNG'),
#  ('과', 'JC'),
#  ('세상', 'NNG'),
#  ('을', 'JKO'),
#  ('연결', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('디스플레이', 'NNG'),
#  (',', 'SC'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('는', 'JX'),
#  ('상상', 'NNG'),
#  ('을', 'JKO'),
#  ('뛰어넘', 'VV'),
#  ('는', 'ETM'),
#  ('혁신', 'NNG'),
#  ('기술', 'NNG'),
#  ('을', 'JKO'),
#  ('통해', 'VV+EC'),
#  ('사람', 'NNG'),
#  ('들', 'XSN'),
#  ('의', 'JKG'),
#  ('삶', 'NNG'),
#  ('에', 'JKB'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('가치', 'NNG'),
#  ('를', 'JKO'),
#  ('더', 'MAG'),
#  ('합니다', 'VV+EF'),
#  ('.', 'SF'),
#  ('CEO', 'SL'),
#  ('MESSAGE', 'SL'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('주식회사', 'NNG'),
#  ('대표', 'NNG'),
#  ('이사', 'NNG'),
#  ('최주선', 'NNP'),
#  ('존경', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('여러분', 'NP'),
#  (',', 'SC'),
#  ('‘', 'SY'),
#  ('격', 'NNG'),
#  ('’', 'SY'),
#  ('이', 'JKS'),
#  ('다른', 'MM'),
#  ('기술', 'NNG'),
#  ('과', 'JC'),
#  ('상품', 'NNG'),
#  ('으로', 'JKB'),
#  ('디스플레이', 'NNG'),
#  ('산업', 'NNG'),
#  ('을', 'JKO'),
#  ('선도', 'NNG'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('글로벌', 'NNG'),
#  ('리딩', 'NNG'),
#  ('기업', 'NNG'),
#  ('으로서', 'JKB'),
#  ('환경', 'NNG'),
#  ('과', 'JC'),
#  ('사회', 'NNG'),
#  ('적', 'XSN'),
#  ('가치', 'NNG'),
#  ('를', 'JKO'),
#  ('‘', 'SY'),
#  ('Samsung', 'SL'),
#  ('Display', 'SL'),
#  ('2025', 'SN'),
#  ('Sustainable', 'SL'),
#  ('Value', 'SL'),
#  ('’', 'SY'),
#  ('로', 'JKB'),
#  ('가장', 'MAG'),
#  ('중요', 'NNG'),
#  ('시', 'XSN'),
#  ('하', 'XSV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('거듭나', 'VV'),
#  ('겠', 'EP'),
#  ('습니다', 'EF'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('는', 'JX'),
#  ('지난해', 'NNG'),
#  ('어려운', 'VA+ETM'),
#  ('여건', 'NNG'),
#  ('속', 'NNG'),
#  ('에서', 'JKB'),
#  ('도', 'JX'),
#  ('뜻깊', 'VA'),
#  ('은', 'ETM'),
#  ('경영', 'NNG'),
#  ('성과', 'NNG'),
#  ('를', 'JKO'),
#  ('COVID', 'SL'),
#  ('-', 'SY'),
#  ('19', 'SN'),
#  ('로', 'JKB'),
#  ('인해', 'VV+EC'),
#  ('우리', 'NP'),
#  ('삶', 'NNG'),
#  ('의', 'JKG'),
#  ('많', 'VA'),
#  ('은', 'ETM'),
#  ('부분', 'NNG'),
#  ('에서', 'JKB'),
#  ('디지털', 'NNG'),
#  ('화', 'XSN'),
#  ('가', 'JKS'),
#  ('급격', 'XR'),
#  ('하', 'XSA'),
#  ('게', 'EC'),
#  ('이뤄냈', 'VV+EC+VX+EP'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('지지', 'NNG'),
#  ('와', 'JC'),
#  ('응원', 'NNG'),
#  ('을', 'JKO'),
#  ('보내', 'VV+EC'),
#  ('주', 'VX'),
#  ('신', 'EP+ETM'),
#  ('고객', 'NNG'),
#  ('및', 'MAJ'),
#  ('협력', 'NNG'),
#  ('회사', 'NNG'),
#  (',', 'SC'),
#  ('임직원', 'NNG'),
#  ('이루어지', 'VV'),
#  ('고', 'EC'),
#  ('있', 'VX'),
#  ('습니다', 'EF'),
#  ('.', 'SF'),
#  ('스마트폰', 'NNP'),
#  ('과', 'JC'),
#  ('노트북', 'NNG'),
#  ('을', 'JKO'),
#  ('통해', 'VV+EC'),
#  ('비대', 'VV'),
#  ('면', 'EC'),
#  ('으로', 'JKB'),
#  ('소통', 'NNG'),
#  ('삼성', 'NNG'),
#  ('디스플레이', 'NNG'),
#  ('는', 'JX'),
#  ('제품', 'NNG'),
#  ('을', 'JKO'),
#  ('생산', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('모든', 'MM'),
#  ('과정', 'NNG'),
#  ('에서', 'JKB'),
#  ('사회', 'NNG'),
#  ('와', 'JC'),
#  ('공동체', 'NNG'),
#  ('의', 'JKG'),
#  ('삼성', 'NNP'),
#  ('디스플레이', 'NNG'),
#  ('는', 'JX'),
#  ('2020', 'SN'),
#  ('년', 'NNBC'),
#  ('하반기', 'NNG'),
#  ('다양', 'NNG'),
#  ('한', 'XSA+ETM'),
#  ('이해', 'NNG'),
#  ('관계자', 'NNG'),
#  ('의', 'JKG'),
#  ('기대', 'NNG'),
#  ('와', 'JC'),
#  ('니즈', 'NNG'),
#  ('들', 'XSN'),
#  ('께', 'JKB'),
#  ('진심', 'NNG'),
#  ('으로', 'JKB'),
#  ('감사', 'NNG'),
#  ('드리', 'VV'),
#  ('며', 'EC'),
#  ('앞', 'NNG'),
#  ('으로', 'JKB'),
#  ('는', 'JX'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('경영', 'NNG'),
#  ('보고서', 'NNG'),
#  ('를', 'JKO'),
#  ('통해', 'VV+EC'),
#  ('하', 'VV'),
#  ('는', 'ETM'),
#  ('삶', 'NNG'),
#  ('이', 'JKS'),
#  ('일상', 'NNG'),
#  ('이', 'JKS'),
#  ('되', 'VV'),
#  ('면서', 'EC'),
#  (',', 'SC'),
#  ('더', 'MAG'),
#  ('나', 'VA'),
#  ('은', 'ETM'),
#  ('화질', 'NNG'),
#  (',', 'SC'),
#  ('새로운', 'VA+ETM'),
#  ('디자인', 'NNG'),
#  ('의', 'JKG'),
#  ('디스플레이', 'NNG'),
#  ('지속', 'NNG'),
#  ('가능', 'NNG'),
#  ('성', 'XSN'),
#  ('을', 'JKO'),
#  ('고려', 'NNG'),
#  ('해', 'XSV+EC'),
#  (',', 'SC'),
#  ('환경', 'NNG'),
#  ('영향', 'NNG'),
#  ('을', 'JKO'),
#  ('최소', 'NNG'),
#  ('화', 'XSN'),
#  ('하', 'XSV'),
#  ('며', 'EC'),
#  ('글로벌', 'NNG'),
#  ('사회', 'NNG'),
#  ('로부터', 'JKB'),
#  ('를', 'NNG+JKO'),
#  ('충족', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('장기', 'NNG'),
#  ('적', 'XSN'),
#  ('인', 'VCP+ETM'),
#  ('가치', 'NNG'),
#  ('창출', 'NNG'),
#  ('을', 'JKO'),
#  ('목표', 'NNG'),
#  ('로', 'JKB'),
#  (',', 'SC'),
#  ('중', 'NNG'),
#  ('장기', 'NNG'),
#  ('ESG', 'SL'),
#  ...]

# %%
from konlpy.tag import Mecab
mecab = Mecab()
stop = ["삼성", "디스플레이", "관리"]
tokens = [token for token in mecab.pos(samsung_display)]

nodes = [t[0] for t in tokens]
vocab = [t[0] for t in tokens if t[0] not in stop if t[1] in ['NNG', 'NNP'] and len(t[0]) > 1]

print(nodes[:10])
print(vocab[:10])
# Out:
# ['SAMSUNG', 'DISPLAY', 'Sustainability', 'Report', '2021', 'SEE', 'THROUGH', '', '', '우리']
# ['지속', '가능', '내일', '세상', '발견', '지구촌', '가족', '세상', '무한', '가능']

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

count = Counter(vocab)
words = dict(count.most_common())

# %%
# %matplotlib inline 
import matplotlib 
from IPython.display import set_matplotlib_formats 
matplotlib.rc('font',family = 'Malgun Gothic') 
set_matplotlib_formats('retina') 
matplotlib.rc('axes',unicode_minus = False)

# %%
wordcloud = WordCloud(font_path = 'C:/Windows/Fonts/malgun.ttf', background_color='white',colormap = "Accent_r", 
                      width=1500, height=1000).generate_from_frequencies(words) 
plt.imshow(wordcloud) 
plt.axis('off') 
plt.show()

# %%
vocab = list(set(vocab))

vocab2idx = {vocab[i]:i for i in range(len(vocab))}
idx2vocab = {i:vocab[i] for i in range(len(vocab))}

# %%
import numpy as np
import math

vocab_len = len(vocab2idx)

# 토큰별로 그래프 edge를 Matrix 형태로 생성
weighted_edge = np.zeros((vocab_len,vocab_len),dtype=np.float32)

# 각 토큰 노드별로 스코어 1로 초기화
score = np.ones((vocab_len),dtype=np.float32)

# coocurrence를 판단하기 위한 window 사이즈 설정
window_size = 4
covered_coocurrences = []

for window_start in range(len(nodes) - window_size + 1):
    window = nodes[window_start:window_start+window_size]
    for i in range(window_size):
        for j in range(i+1, window_size):
            if window[i] in vocab and window[j] in vocab:
                index_i = window_start + i
                index_j = window_start + j

                if (index_i, index_j) not in covered_coocurrences:
                    weighted_edge[vocab2idx[window[i]]][vocab2idx[window[j]]] = 1
                    weighted_edge[vocab2idx[window[j]]][vocab2idx[window[i]]] = 1
                    covered_coocurrences.append((index_i, index_j))

for i in range(vocab_len):
    row_sum = weighted_edge[i].sum()
    weighted_edge[i] = weighted_edge[i]/row_sum if row_sum > 0 else 0

MAX_ITERATIONS = 50
d=0.85
threshold = 0.0001 #convergence threshold

for iter in range(MAX_ITERATIONS):
    prev_score = np.copy(score)

    for i in range(vocab_len):
        summation = 0
        for j in range(vocab_len):
            if weighted_edge[j][i] != 0:
                summation += weighted_edge[j][i] * prev_score[j]

        score[i] = (1 - d) * d*summation

    if np.sum(np.fabs(prev_score -  score)) <= threshold:
        break


sorted_index = np.flip(np.argsort(score), 0)

n = 50


print("\n=== 핵심키워드 ===")
for i in range(0,n):
    print(str(idx2vocab[sorted_index[i]])+" : " + str(score[sorted_index[i]]))
# Out:
# === 핵심키워드 ===
# 환경 : 2.0532282e-08
# 임직원 : 1.9838414e-08
# 안전 : 1.8050772e-08
# 운영 : 1.7436182e-08
# 회사 : 1.7077904e-08
# 활동 : 1.6829931e-08
# 지원 : 1.6536386e-08
# 교육 : 1.5919987e-08
# 협력 : 1.5456763e-08
# 개선 : 1.5261017e-08
# 정보 : 1.4246694e-08
# 경영 : 1.3577339e-08
# 지속 : 1.3277584e-08
# 제품 : 1.2812051e-08
# 사회 : 1.235914e-08
# 사업장 : 1.2165068e-08
# 가능 : 1.1660423e-08
# 사용 : 1.1406237e-08
# 기업 : 1.1288607e-08
# 기술 : 1.1235045e-08
# 지역 : 1.1024713e-08
# 사내 : 1.0688035e-08
# 보호 : 1.06716636e-08
# 기준 : 1.0501031e-08
# 관련 : 1.0492387e-08
# 에너지 : 1.0374051e-08
# 사업 : 1.0106215e-08
# 평가 : 1.0081555e-08
# 산안 : 1.0059255e-08
# 인증 : 9.2782635e-09
# 조직 : 9.23292e-09
# 대응 : 9.225745e-09
# 문화 : 9.183638e-09
# 주요 : 9.119972e-09
# 개발 : 9.029304e-09
# 물질 : 8.973046e-09
# 진행 : 8.914113e-09
# 프로세스 : 8.906623e-09
# 대상 : 8.895576e-09
# 예방 : 8.879608e-09
# 강화 : 8.608413e-09
# 사항 : 8.547235e-09
# 고객 : 8.521923e-09
# 다양 : 8.512289e-09
# 개인 : 8.168265e-09
# 리스크 : 8.141652e-09
# 노력 : 8.103067e-09
# 공정 : 8.0857525e-09
# 시스템 : 7.990379e-09
# 기반 : 7.680617e-09

# %%
keyword = []
for i in range(0,15):
    keyword.append(str(idx2vocab[sorted_index[i]]))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

n_topic = 3

tfidf_vect = TfidfVectorizer()
tfidf = tfidf_vect.fit_transform(keyword)
svd = TruncatedSVD(n_components=n_topic, n_iter=100)

U = svd.fit_transform(tfidf)
Vt = svd.components_

# %%
vocab = tfidf_vect.get_feature_names()
print(vocab)
n = 3
for i, topic in enumerate(Vt):
    print("Topic {}".format(i), [ (vocab[i], topic[i], round(3)) for i in topic.argsort()[:-n-1:-1]])
# Out:
# ['개선', '경영', '교육', '사회', '안전', '운영', '임직원', '정보', '제품', '지속', '지원', '협력', '환경', '활동', '회사']
# Topic 0 [('사회', 0.6611422231484414, 3), ('지원', 0.532766860057389, 3), ('교육', 0.3050671511962771, 3)]
# Topic 1 [('임직원', 0.5488139115238004, 3), ('경영', 0.4209043272985842, 3), ('협력', 0.38269095604105824, 3)]
# Topic 2 [('운영', 0.6411250910002075, 3), ('정보', 0.4510410782875297, 3), ('지속', 0.3959399055899916, 3)]

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

def calc_simiarlty_matrix(vectors):
    def consine_similarity(a,b):
        return dot(a,b)/(norm(a)*norm(b))
    
    n_word = len(vectors)
    similarity_matrix = np.zeros((n_word, n_word))
    
    for i in range(n_word):
        for j in range(n_word):
            similarity_matrix[j, i] = consine_similarity(vectors[i], vectors[j]).round(4)

    return similarity_matrix

# %%
word_vectors = Vt.T
word_similarity_matrix = calc_simiarlty_matrix(word_vectors)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_similarity(similarity_matrix, label):
    mask = np.triu(np.ones_like(similarity_matrix, dtype=np.bool))
    plt.rcParams['figure.figsize'] = [8, 6]
    plt.rc('font', family='Malgun Gothic')
    ax = sns.heatmap(similarity_matrix, mask=mask, xticklabels=label, yticklabels=label,
                     annot=True, fmt=".2f", annot_kws={"size":8},cmap="coolwarm")

# %%
visualize_similarity(word_similarity_matrix, vocab)

# %%
from sklearn.manifold import TSNE

def visualize_vectors(vectors, labels):
    tsne = TSNE(n_components=2, n_iter=10000, perplexity=2)
    np.set_printoptions(suppress=True)
    T = tsne.fit_transform(vectors)

    plt.figure(figsize=(10, 6))
    plt.scatter(T[:,0], T[:, 1], c='orange', edgecolors='r')
    for label, x, y in zip(labels, T[:,0], T[:, 1]):
        plt.annotate(label, xy=(x+1, y+1), xytext=(0, 0), textcoords='offset points')

# %%
visualize_vectors(word_vectors, vocab)
